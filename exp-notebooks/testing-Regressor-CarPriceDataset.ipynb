# %%
import sys
import time
sys.path.insert(0, '/home/anish/AutoNN')

# %%
import os 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
from AutoNN.preprocessing import data_cleaning as dc
import dask.dataframe as dd

# %%
df = dd.read_csv("/home/anish/Downloads/CarPrice_Assignment.csv", assume_missing=True)

# %%
df.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0     1.0        3.0        alfa-romero giulia      gas        std        two
# 1     2.0        3.0       alfa-romero stelvio      gas        std        two
# 2     3.0        1.0  alfa-romero Quadrifoglio      gas        std        two
# 3     4.0        2.0               audi 100 ls      gas        std       four
# 4     5.0        2.0                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...       130.0
# 1  convertible        rwd          front       88.6  ...       130.0
# 2    hatchback        rwd          front       94.5  ...       152.0
# 3        sedan        fwd          front       99.8  ...       109.0
# 4        sedan        4wd          front       99.4  ...       136.0
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0      111.0   5000.0    21.0
# 1        mpfi       3.47    2.68              9.0      111.0   5000.0    21.0
# 2        mpfi       2.68    3.47              9.0      154.0   5000.0    19.0
# 3        mpfi       3.19    3.40             10.0      102.0   5500.0    24.0
# 4        mpfi       3.19    3.40              8.0      115.0   5500.0    18.0
#
#    highwaympg    price
# 0        27.0  13495.0
# 1        27.0  16500.0
# 2        26.0  16500.0
# 3        30.0  13950.0
# 4        22.0  17450.0
#
# [5 rows x 26 columns]

# %%
df.compute().shape
# Out:
# (205, 26)

# %%
df = df.dropna()
df = df.reset_index(drop=True)

# %%
df.compute().shape
# Out:
# (205, 26)

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0     1.0        3.0        alfa-romero giulia      gas        std        two
# 1     2.0        3.0       alfa-romero stelvio      gas        std        two
# 2     3.0        1.0  alfa-romero Quadrifoglio      gas        std        two
# 3     4.0        2.0               audi 100 ls      gas        std       four
# 4     5.0        2.0                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...       130.0
# 1  convertible        rwd          front       88.6  ...       130.0
# 2    hatchback        rwd          front       94.5  ...       152.0
# 3        sedan        fwd          front       99.8  ...       109.0
# 4        sedan        4wd          front       99.4  ...       136.0
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0      111.0   5000.0    21.0
# 1        mpfi       3.47    2.68              9.0      111.0   5000.0    21.0
# 2        mpfi       2.68    3.47              9.0      154.0   5000.0    19.0
# 3        mpfi       3.19    3.40             10.0      102.0   5500.0    24.0
# 4        mpfi       3.19    3.40              8.0      115.0   5500.0    18.0
#
#    highwaympg    price
# 0        27.0  13495.0
# 1        27.0  16500.0
# 2        26.0  16500.0
# 3        30.0  13950.0
# 4        22.0  17450.0
#
# [5 rows x 26 columns]

# %%
data_cl = dc.DataCleaning(train_dataframe=df, label=['price'])
# Out:
# []

# %%
data_cl.dataset.get()[0].head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0     1.0        3.0        alfa-romero giulia      gas        std        two
# 1     2.0        3.0       alfa-romero stelvio      gas        std        two
# 2     3.0        1.0  alfa-romero Quadrifoglio      gas        std        two
# 3     4.0        2.0               audi 100 ls      gas        std       four
# 4     5.0        2.0                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...       130.0
# 1  convertible        rwd          front       88.6  ...       130.0
# 2    hatchback        rwd          front       94.5  ...       152.0
# 3        sedan        fwd          front       99.8  ...       109.0
# 4        sedan        4wd          front       99.4  ...       136.0
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0      111.0   5000.0    21.0
# 1        mpfi       3.47    2.68              9.0      111.0   5000.0    21.0
# 2        mpfi       2.68    3.47              9.0      154.0   5000.0    19.0
# 3        mpfi       3.19    3.40             10.0      102.0   5500.0    24.0
# 4        mpfi       3.19    3.40              8.0      115.0   5500.0    18.0
#
#    highwaympg    price
# 0        27.0  13495.0
# 1        27.0  16500.0
# 2        26.0  16500.0
# 3        30.0  13950.0
# 4        22.0  17450.0
#
# [5 rows x 26 columns]

# %%
data_cl.col_info
# Out:
# {'car_ID': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 205},
#  'symboling': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 6},
#  'CarName': {'dtype': dtype('O'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 147},
#  'fueltype': {'dtype': dtype('O'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 2},
#  'aspiration': {'dtype': dtype('O'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 2},
#  'doornumber': {'dtype': dtype('O'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 2},
#  'carbody': {'dtype': dtype('O'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 5},
#  'drivewheel': {'dtype': dtype('O'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 3},
#  'enginelocation': {'dtype': dtype('O'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 2},
#  'wheelbase': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 53},
#  'carlength': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 75},
#  'carwidth': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 44},
#  'carheight': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 49},
#  'curbweight': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 171},
#  'enginetype': {'dtype': dtype('O'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 7},
#  'cylindernumber': {'dtype': dtype('O'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 7},
#  'enginesize': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 44},
#  'fuelsystem': {'dtype': dtype('O'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 8},
#  'boreratio': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 38},
#  'stroke': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 37},
#  'compressionratio': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 32},
#  'horsepower': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 59},
#  'peakrpm': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 23},
#  'citympg': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 29},
#  'highwaympg': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 30},
#  'price': {'dtype': dtype('float64'),
#   'is_label': True,
#   'missing': 0.0,
#   'cardinality': 189}}

# %%
data_cl.encode()

# %%
data_cl.dataset.get()[0].head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0     1.0        3.0        0         0           0           0        0
# 1     2.0        3.0        1         0           0           0        0
# 2     3.0        1.0        2         0           0           0        1
# 3     4.0        2.0        3         0           0           1        2
# 4     5.0        2.0        4         0           0           1        2
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           0               0       88.6  ...       130.0           0
# 1           0               0       88.6  ...       130.0           0
# 2           0               0       94.5  ...       152.0           0
# 3           1               0       99.8  ...       109.0           0
# 4           2               0       99.4  ...       136.0           0
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0       111.0   5000.0     21.0
# 1       3.47    2.68               9.0       111.0   5000.0     21.0
# 2       2.68    3.47               9.0       154.0   5000.0     19.0
# 3       3.19    3.40              10.0       102.0   5500.0     24.0
# 4       3.19    3.40               8.0       115.0   5500.0     18.0
#
#    highwaympg    price
# 0        27.0  13495.0
# 1        27.0  16500.0
# 2        26.0  16500.0
# 3        30.0  13950.0
# 4        22.0  17450.0
#
# [5 rows x 26 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler_x = MinMaxScaler()
scaler_x.fit(data_cl.dataset.get()[0])
scaled_np_arr = scaler_x.transform(data_cl.dataset.get()[0])

# %%
scaled_np_arr
# Out:
# array([[0.        , 1.        , 0.        , ..., 0.22222222, 0.28947368,
#         0.20795889],
#        [0.00490196, 1.        , 0.00684932, ..., 0.22222222, 0.28947368,
#         0.28255797],
#        [0.00980392, 0.6       , 0.01369863, ..., 0.16666667, 0.26315789,
#         0.28255797],
#        ...,
#        [0.99019608, 0.2       , 0.97260274, ..., 0.13888889, 0.18421053,
#         0.40631051],
#        [0.99509804, 0.2       , 1.        , ..., 0.36111111, 0.28947368,
#         0.43076312],
#        [1.        , 0.2       , 0.98630137, ..., 0.16666667, 0.23684211,
#         0.43461099]])

# %%
import numpy as np

# %%
from AutoNN.networkbuilding import final
# Out:
# 2022-09-19 22:05:12.329915: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
data_cl.dataset.train_test_split()

# %%
[traindf, testdf] = data_cl.dataset.get(types=['train', 'test'])

# %%
traindf.compute()
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 59     60.0        1.0       47         0           0           0        1
# 63     64.0        0.0       46         1           0           1        2
# 175   176.0       -1.0      113         0           0           1        1
# 110   111.0        0.0       84         1           1           1        3
# 100   101.0        0.0       78         0           0           1        2
# ..      ...        ...      ...       ...         ...         ...      ...
# 7       8.0        1.0        6         0           0           1        3
# 73     74.0        0.0       59         0           0           1        2
# 162   163.0        0.0      118         0           0           1        2
# 31     32.0        2.0       28         0           0           0        1
# 193   194.0        0.0      135         0           0           1        3
#
#      drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 59            1               0       98.8  ...       122.0           1
# 63            1               0       98.8  ...       122.0           6
# 175           1               0      102.4  ...       122.0           0
# 110           0               0      114.2  ...       152.0           6
# 100           1               0       97.2  ...       120.0           1
# ..          ...             ...        ...  ...         ...         ...
# 7             1               0      105.8  ...       136.0           0
# 73            0               0      120.9  ...       308.0           0
# 162           1               0       95.7  ...        98.0           1
# 31            1               0       86.6  ...        92.0           3
# 193           1               0      100.4  ...       109.0           0
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 59        3.39    3.39               8.6        84.0   4800.0     26.0
# 63        3.39    3.39              22.7        64.0   4650.0     36.0
# 175       3.31    3.54               8.7        92.0   4200.0     27.0
# 110       3.70    3.52              21.0        95.0   4150.0     25.0
# 100       3.33    3.47               8.5        97.0   5200.0     27.0
# ..         ...     ...               ...         ...      ...      ...
# 7         3.19    3.40               8.5       110.0   5500.0     19.0
# 73        3.80    3.35               8.0       184.0   4500.0     14.0
# 162       3.19    3.03               9.0        70.0   4800.0     28.0
# 31        2.91    3.41               9.2        76.0   6000.0     31.0
# 193       3.19    3.40               9.0        88.0   5500.0     25.0
#
#      highwaympg    price
# 59         32.0   8845.0
# 63         42.0  10795.0
# 175        32.0   9988.0
# 110        25.0  13860.0
# 100        34.0   9549.0
# ..          ...      ...
# 7          25.0  18920.0
# 73         16.0  40960.0
# 162        34.0   9258.0
# 31         38.0   6855.0
# 193        31.0  12290.0
#
# [160 rows x 26 columns]

# %%
y_train = traindf.pop(data_cl.get_label()[0])
X_train = traindf

# %%
y_test = testdf.pop(data_cl.get_label()[0])
X_test = testdf

# %%
testdf.compute().shape
# Out:
# (45, 25)

# %%
scaler_x = MinMaxScaler()
scaler_x.fit(X_train)
X_train = scaler_x.transform(X_train)
X_test = scaler_x.transform(X_test)

# %%
y_train = np.asarray(y_train).reshape([-1, 1])
y_test = np.asarray(y_test).reshape([-1, 1])

# %%
y_train.shape
# Out:
# (160, 1)

# %%
import time

# %%
start = time.time()
f = final.Final(X_train, y_train, X_test, y_test, "mean_absolute_percentage_error", 40, 64, input_shape = 25, 
                                   max_no_layers = 3, model_per_batch = 10, output_activation = None)
f.get_all_best_models()
end = time.time()
print("Time Taken : ", end-start)
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f333f2e64c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#
#
#
# loss  :  953.8607177734375 , TEST :  952.2561645507812
# output_layer_dense_16_16_loss  :  99.89200592041016 , TEST :  99.88921356201172
# output_layer_dense_16_64_loss  :  99.6141357421875 , TEST :  99.59974670410156
# output_layer_dense_16_128_loss  :  99.2478256225586 , TEST :  99.22352600097656
# output_layer_dense_16_512_loss  :  97.1047592163086 , TEST :  96.99534606933594
# output_layer_dense_16_1024_loss  :  94.44572448730469 , TEST :  94.24142456054688
# output_layer_dense_64_16_loss  :  99.73292541503906 , TEST :  99.72608184814453
# output_layer_dense_64_64_loss  :  98.19149017333984 , TEST :  98.13028717041016
# output_layer_dense_64_128_loss  :  97.6646499633789 , TEST :  97.58209991455078
# output_layer_dense_64_512_loss  :  88.49159240722656 , TEST :  88.1007080078125
# output_layer_dense_64_1024_loss  :  79.47570037841797 , TEST :  78.76777648925781
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f333d19cee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f3374343c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#
#
#
# loss  :  104.73470306396484 , TEST :  115.56258392333984
# output_layer_dense_1024_1024_16_loss  :  25.084712982177734 , TEST :  28.69410514831543
# output_layer_dense_1024_1024_64_loss  :  23.025348663330078 , TEST :  26.398372650146484
# output_layer_dense_1024_1024_128_loss  :  21.901779174804688 , TEST :  24.80571746826172
# output_layer_dense_1024_1024_512_loss  :  18.5220890045166 , TEST :  19.611631393432617
# output_layer_dense_1024_1024_1024_loss  :  16.20077133178711 , TEST :  16.052764892578125
#
# -------------------------------------------------------------------------------
# [{'model_name': 'dense_1024_1024_1024', 'score': 16.052764892578125, 'path_weights': '/home/anish/AutoNN_test_weights/dense_1024_1024_1024', 'model_conf': ['', 25, 3, 'relu', {'layer1': 1024, 'layer2': 1024, 'layer3': 1024}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f332b25e790>}, {'model_name': 'dense_512_1024_1024', 'score': 18.59453582763672, 'path_weights': '/home/anish/AutoNN_test_weights/dense_512_1024_1024', 'model_conf': ['', 25, 3, 'relu', {'layer1': 512, 'layer2': 1024, 'layer3': 1024}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3350fd2cd0>}, {'model_name': 'dense_1024_1024_512', 'score': 19.611631393432617, 'path_weights': '/home/anish/AutoNN_test_weights/dense_1024_1024_512', 'model_conf': ['', 25, 3, 'relu', {'layer1': 1024, 'layer2': 1024, 'layer3': 512}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3374ff0ee0>}, {'model_name': 'dense_512_512_1024', 'score': 21.57242202758789, 'path_weights': '/home/anish/AutoNN_test_weights/dense_512_512_1024', 'model_conf': ['', 25, 3, 'relu', {'layer1': 512, 'layer2': 512, 'layer3': 1024}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f335104fb80>}, {'model_name': 'dense_512_1024_512', 'score': 22.28237533569336, 'path_weights': '/home/anish/AutoNN_test_weights/dense_512_1024_512', 'model_conf': ['', 25, 3, 'relu', {'layer1': 512, 'layer2': 1024, 'layer3': 512}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3350fd2940>}]
#
# -------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Model Name : dense_1024_1024_1024_dr
#
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f337423c040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f335102d790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# BEST HYPERPARAMETERS : BEST_LOSS : 8.621047973632812, BEST_ACTIVATION : selu, BEST_INITIALIZER : LecunNormal, BEST_LEARINING_RATE : 0.01, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.5, BEST_DROPOUT_LOSS : 9.004510879516602
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f333d5229d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#
#
#
# loss  :  7.1351470947265625 , TEST :  10.593026161193848
# --------------------------------------------------------------------------------
# Model Name : dense_512_1024_1024_dr
#
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f333e8101f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32f53508b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# BEST HYPERPARAMETERS : BEST_LOSS : 8.74166488647461, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotNormal, BEST_LEARINING_RATE : 0.01, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : 0.2, BEST_DROPOUT_LOSS : 8.480123519897461
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32f4a7c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#
#
#
# loss  :  7.117441654205322 , TEST :  11.68089485168457
# --------------------------------------------------------------------------------
# Model Name : dense_1024_1024_512_dr
#
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32f17a7790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32d5327820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# BEST HYPERPARAMETERS : BEST_LOSS : 8.68792724609375, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotNormal, BEST_LEARINING_RATE : 0.01585, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 10.27225399017334
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32d3a468b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#
#
#
# loss  :  7.577977180480957 , TEST :  11.903751373291016
# --------------------------------------------------------------------------------
# Model Name : dense_512_512_1024_dr
#
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32d1851700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32dd3dd8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# BEST HYPERPARAMETERS : BEST_LOSS : 9.086992263793945, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotUniform, BEST_LEARINING_RATE : 0.02512, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : 0.2, BEST_DROPOUT_LOSS : 8.14215087890625
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32e6b11790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#
#
#
# loss  :  9.229487419128418 , TEST :  12.413392066955566
# --------------------------------------------------------------------------------
# Model Name : dense_512_1024_512_dr
#
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32b190f790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32969821f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# BEST HYPERPARAMETERS : BEST_LOSS : 8.467218399047852, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotUniform, BEST_LEARINING_RATE : 0.01585, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 8.373406410217285
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32936caaf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#
#
#
# loss  :  7.195249080657959 , TEST :  11.264517784118652
# [{'model_name': 'dense_1024_1024_1024_dr', 'score': 10.593026161193848, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_1024_1024_1024_dr', 'model_conf': ['', 25, 3, 'relu', {'layer1': 1024, 'layer2': 1024, 'layer3': 1024}, [1, None], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f357f769760>}, {'model_name': 'dense_512_1024_512_dr', 'score': 11.264517784118652, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_512_1024_512_dr', 'model_conf': ['', 25, 3, 'relu', {'layer1': 512, 'layer2': 1024, 'layer3': 512}, [1, None], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f32ed22c550>}, {'model_name': 'dense_512_1024_1024_dr', 'score': 11.68089485168457, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_512_1024_1024_dr', 'model_conf': ['', 25, 3, 'relu', {'layer1': 512, 'layer2': 1024, 'layer3': 1024}, [1, None], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3350ddcaf0>}]
# 2022-09-19 22:11:57.999068: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_1024_1024_1024_dr/assets
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_512_1024_512_dr/assets
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_512_1024_1024_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_1024_1024_1024_dr_st_dense_512_1024_512_dr
# Model: "dense_1024_1024_1024_dr_st_dense_512_1024_512_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_1024_1024_ [(None, 25)]              0
# _________________________________________________________________
# layer1_dense_1024_1024_1024_ (None, 1024)              26624
# _________________________________________________________________
# layer2_dense_1024_1024_1024_ (None, 1024)              1049600
# _________________________________________________________________
# layer3_dense_1024_1024_1024_ (None, 1024)              1049600
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# layer1_dense_512_1024_512_dr (None, 512)               524800
# _________________________________________________________________
# layer2_dense_512_1024_512_dr (None, 1024)              525312
# _________________________________________________________________
# layer3_dense_512_1024_512_dr (None, 512)               524800
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# output_layer_dense_512_1024_ (None, 1)                 513
# =================================================================
# Total params: 3,701,249
# Trainable params: 3,701,249
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32918f9820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# BEST HYPERPARAMETERS : BEST_LOSS : 6.913613796234131, BEST_ACTIVATION : selu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00501, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# LecunUniform
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32c2594430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32cd2b04c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32e8522700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32d534c4c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32ba3b0430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32d97201f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32d073c0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# DROPOUT RATES : [0.2, 0]
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32c621edc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# TRAIN_LOSS = 5.574536323547363, TEST_LOSS = 12.105462074279785
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_1024_1024_1024_dr_st_dense_512_1024_512_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_1024_1024_1024_dr_st_dense_512_1024_1024_dr
# Model: "dense_1024_1024_1024_dr_st_dense_512_1024_1024_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_1024_1024_ [(None, 25)]              0
# _________________________________________________________________
# layer1_dense_1024_1024_1024_ (None, 1024)              26624
# _________________________________________________________________
# layer2_dense_1024_1024_1024_ (None, 1024)              1049600
# _________________________________________________________________
# layer3_dense_1024_1024_1024_ (None, 1024)              1049600
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# layer1_dense_512_1024_1024_d (None, 512)               524800
# _________________________________________________________________
# layer2_dense_512_1024_1024_d (None, 1024)              525312
# _________________________________________________________________
# layer3_dense_512_1024_1024_d (None, 1024)              1049600
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# output_layer_dense_512_1024_ (None, 1)                 1025
# =================================================================
# Total params: 4,226,561
# Trainable params: 4,226,561
# Non-trainable params: 0
# _________________________________________________________________
# None
# ...
# None
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32de484b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# BEST HYPERPARAMETERS : BEST_LOSS : 7.532324314117432, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotUniform, BEST_LEARINING_RATE : 0.002, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# GlorotUniform
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f3264f32430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32ee39dee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32eafff430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32bfab25e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32f3a1e310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32cd2eb820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f3291cc38b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# DROPOUT RATES : [0.2, 0]
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32ab12eaf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# TRAIN_LOSS = 5.16243839263916, TEST_LOSS = 11.524518966674805
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_512_1024_1024_dr_st_dense_1024_1024_1024_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_512_1024_1024_dr_st_dense_512_1024_512_dr
# Model: "dense_512_1024_1024_dr_st_dense_512_1024_512_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_512_1024_1 [(None, 25)]              0
# _________________________________________________________________
# layer1_dense_512_1024_1024_d (None, 512)               13312
# _________________________________________________________________
# layer2_dense_512_1024_1024_d (None, 1024)              525312
# _________________________________________________________________
# layer3_dense_512_1024_1024_d (None, 1024)              1049600
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# layer1_dense_512_1024_512_dr (None, 512)               524800
# _________________________________________________________________
# layer2_dense_512_1024_512_dr (None, 1024)              525312
# _________________________________________________________________
# layer3_dense_512_1024_512_dr (None, 512)               524800
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 512)               0
# _________________________________________________________________
# output_layer_dense_512_1024_ (None, 1)                 513
# =================================================================
# Total params: 3,163,649
# Trainable params: 3,163,649
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32b9b28310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# BEST HYPERPARAMETERS : BEST_LOSS : 7.554238796234131, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotUniform, BEST_LEARINING_RATE : 0.00158, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# GlorotUniform
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f328f4db550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32cc160430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32b6a81940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32ee360c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32ced24280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f3291b0d040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f3291b7e430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# DROPOUT RATES : [0.2, 0.2]
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_test_function.<locals>.test_function at 0x7f32aa069040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# TRAIN_LOSS = 5.36150598526001, TEST_LOSS = 10.471390724182129
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_512_1024_1024_dr_st_dense_512_1024_512_dr/assets
# Time Taken :  814.2806227207184

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model("/home/anish/ASC_ML_test_weights/candidate_models/dense_64_64_16_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
model = load_model("/home/anish/ASC_ML_test_weights/candidate_models/dense_64_64_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
model = load_model("/home/anish/ASC_ML_test_weights/stacked_models/dense_64_64_16_dr_st_dense_64_64_16_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
model = load_model("/home/anish/ASC_ML_test_weights/stacked_models/dense_64_64_16_dr_st_dense_64_64_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
model = load_model("/home/anish/ASC_ML_test_weights/stacked_models/dense_64_64_dr_st_dense_64_64_16_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
model = load_model("/home/anish/ASC_ML_test_weights/stacked_models/dense_64_64_dr_st_dense_64_64_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# making predictions on the testing set
y_pred = gnb.predict(X_test)

# comparing actual response values (y_test) with predicted response values (y_pred)
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)

# %%
y_pred_train = gnb.predict(X_train)
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_train, y_pred_train)*100)
