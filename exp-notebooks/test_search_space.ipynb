# %%
import sys
sys.path.insert(0, '/home/anish/ASC_ML')

# %%
from ASC_ML import search_space_gen_v1 as search
# Out:
# 2022-06-15 18:14:48.781599: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
s = search.Search_Space_Gen_1(max_no_layers = 3, input_shape = 8)

# %%
s.all_layer_perm
# Out:
# [[(16, 16),
#   (16, 32),
#   (16, 64),
#   (16, 128),
#   (16, 196),
#   (16, 256),
#   (32, 16),
#   (32, 32),
#   (32, 64),
#   (32, 128),
#   (32, 196),
#   (32, 256),
#   (64, 16),
#   (64, 32),
#   (64, 64),
#   (64, 128),
#   (64, 196),
#   (64, 256),
#   (128, 16),
#   (128, 32),
#   (128, 64),
#   (128, 128),
#   (128, 196),
#   (128, 256),
#   (196, 16),
#   (196, 32),
#   (196, 64),
#   (196, 128),
#   (196, 196),
#   (196, 256),
#   (256, 16),
#   (256, 32),
#   (256, 64),
#   (256, 128),
#   (256, 196),
#   (256, 256)],
#  [(16, 16, 16),
#   (16, 16, 32),
#   (16, 16, 64),
#   (16, 16, 128),
#   (16, 16, 196),
#   (16, 16, 256),
#   (16, 32, 16),
#   (16, 32, 32),
#   (16, 32, 64),
#   (16, 32, 128),
#   (16, 32, 196),
#   (16, 32, 256),
#   (16, 64, 16),
#   (16, 64, 32),
#   (16, 64, 64),
#   (16, 64, 128),
#   (16, 64, 196),
#   (16, 64, 256),
#   (16, 128, 16),
#   (16, 128, 32),
#   (16, 128, 64),
#   (16, 128, 128),
#   (16, 128, 196),
#   (16, 128, 256),
# ...

# %%
a = s.all_layer_perm[0]
d = {}
for layer_sizes in a:
    for layer_size,i in zip(layer_sizes, range(1,len(layer_sizes)+1)):
        layer_name = "layer" + str(i)
        d.update({layer_name:layer_size})
    print(d)
    d.clear()
# Out:
# {'layer1': 16, 'layer2': 16}
# {'layer1': 16, 'layer2': 32}
# {'layer1': 16, 'layer2': 64}
# {'layer1': 16, 'layer2': 128}
# {'layer1': 16, 'layer2': 196}
# {'layer1': 16, 'layer2': 256}
# {'layer1': 32, 'layer2': 16}
# {'layer1': 32, 'layer2': 32}
# {'layer1': 32, 'layer2': 64}
# {'layer1': 32, 'layer2': 128}
# {'layer1': 32, 'layer2': 196}
# {'layer1': 32, 'layer2': 256}
# {'layer1': 64, 'layer2': 16}
# {'layer1': 64, 'layer2': 32}
# {'layer1': 64, 'layer2': 64}
# {'layer1': 64, 'layer2': 128}
# {'layer1': 64, 'layer2': 196}
# {'layer1': 64, 'layer2': 256}
# {'layer1': 128, 'layer2': 16}
# {'layer1': 128, 'layer2': 32}
# {'layer1': 128, 'layer2': 64}
# {'layer1': 128, 'layer2': 128}
# {'layer1': 128, 'layer2': 196}
# {'layer1': 128, 'layer2': 256}
# {'layer1': 196, 'layer2': 16}
# {'layer1': 196, 'layer2': 32}
# {'layer1': 196, 'layer2': 64}
# {'layer1': 196, 'layer2': 128}
# {'layer1': 196, 'layer2': 196}
# {'layer1': 196, 'layer2': 256}
# {'layer1': 256, 'layer2': 16}
# ...

# %%
len(s.all_layer_perm[1])
# Out:
# 216

# %%
s._get_all_models()
# Out:
# 2022-06-08 15:38:46.311890: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-08 15:38:46.312510: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-06-08 15:38:46.356419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-08 15:38:46.356549: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.695GHz coreCount: 30 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 312.97GiB/s
# 2022-06-08 15:38:46.356564: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# from numba import cuda
# cuda.select_device(0)
# cuda.close()

# %%
s.all_model_list
# Out:
# [[<ASC_ML.model_generation.NN_ModelGeneration at 0x7fb97c18b040>,
# ...

# %%
print(len(s.all_model_list[0]))
print(len(s.all_model_list[1]))
# Out:
# 36
# 216

# %%
s.all_model_list[1][215].model.summary()
# Out:
# Model: "dense_256_256_256"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_layer_dense_256_256_25 [(None, 8)]               0
# _________________________________________________________________
# layer1_dense_256_256_256 (De (None, 256)               2304
# _________________________________________________________________
# layer2_dense_256_256_256 (De (None, 256)               65792
# _________________________________________________________________
# layer3_dense_256_256_256 (De (None, 256)               65792
# _________________________________________________________________
# output_layer_dense_256_256_2 (None, 1)                 257
# ...
# Total params: 134,145
# Trainable params: 134,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %%
from keras.backend.tensorflow_backend import set_session
from keras.backend.tensorflow_backend import clear_session
from keras.backend.tensorflow_backend import get_session
import tensorflow

# Reset Keras Session
def reset_keras():
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()

    try:
        del classifier # this is from global space - change this as you need
    except:
        pass

    print(gc.collect()) # if it's done something you should see a number being outputted

    # use the same config as you used to create the session
    config = tensorflow.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 1
    config.gpu_options.visible_device_list = "0"
    set_session(tensorflow.Session(config=config))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4118/1706497088.py in <module>
# ----> 1 from keras.backend.tensorflow_backend import set_session
#       2 from keras.backend.tensorflow_backend import clear_session
#       3 from keras.backend.tensorflow_backend import get_session
#       4 import tensorflow
#       5
#
# ModuleNotFoundError: No module named 'keras'

# %%
del s
