# %%
import sys
import time
sys.path.insert(0, '/home/anish/AutoNN')

# %%
from AutoNN.preprocessing import data_cleaning as dc
import dask.dataframe as dd

# %%
df = dd.read_csv("/home/anish/Downloads/diabetes.csv", assume_missing=True)

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0      1.0
# 1                     0.351  31.0      0.0
# 2                     0.672  32.0      1.0
# 3                     0.167  21.0      0.0
# 4                     2.288  33.0      1.0

# %%
df = df.dropna()
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0      1.0
# 1                     0.351  31.0      0.0
# 2                     0.672  32.0      1.0
# 3                     0.167  21.0      0.0
# 4                     2.288  33.0      1.0

# %%
data_cl = dc.DataCleaning(train_dataframe=df, label=['Outcome'])
# Out:
# []

# %%
data_cl.dataset.get()[0].head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0      1.0
# 1                     0.351  31.0      0.0
# 2                     0.672  32.0      1.0
# 3                     0.167  21.0      0.0
# 4                     2.288  33.0      1.0

# %%
data_cl.col_info
# Out:
# {'Pregnancies': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 17},
#  'Glucose': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 136},
#  'BloodPressure': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 47},
#  'SkinThickness': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 51},
#  'Insulin': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 186},
#  'BMI': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 248},
#  'DiabetesPedigreeFunction': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 517},
#  'Age': {'dtype': dtype('float64'),
#   'is_label': False,
#   'missing': 0.0,
#   'cardinality': 52},
#  'Outcome': {'dtype': dtype('float64'),
#   'is_label': True,
#   'missing': 0.0,
#   'cardinality': 2}}

# %%
data_cl.encode()

# %%
data_cl.dataset.get()[0].head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0      1.0
# 1                     0.351  31.0      0.0
# 2                     0.672  32.0      1.0
# 3                     0.167  21.0      0.0
# 4                     2.288  33.0      1.0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler_x = MinMaxScaler()
scaler_x.fit(data_cl.dataset.get()[0])
scaled_np_arr = scaler_x.transform(data_cl.dataset.get()[0])

# %%
scaled_np_arr
# Out:
# array([[0.35294118, 0.74371859, 0.59016393, ..., 0.23441503, 0.48333333,
#         1.        ],
#        [0.05882353, 0.42713568, 0.54098361, ..., 0.11656704, 0.16666667,
#         0.        ],
#        [0.47058824, 0.91959799, 0.52459016, ..., 0.25362938, 0.18333333,
#         1.        ],
#        ...,
#        [0.29411765, 0.6080402 , 0.59016393, ..., 0.07130658, 0.15      ,
#         0.        ],
#        [0.05882353, 0.63316583, 0.49180328, ..., 0.11571307, 0.43333333,
#         1.        ],
#        [0.05882353, 0.46733668, 0.57377049, ..., 0.10119556, 0.03333333,
#         0.        ]])

# %%
import numpy as np

# %%
from AutoNN.networkbuilding import final
# Out:
# 2022-09-19 18:28:30.866068: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
data_cl.dataset.train_test_split()

# %%
[traindf, testdf] = data_cl.dataset.get(types=['train', 'test'])

# %%
traindf.compute()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 174          2.0     75.0           64.0           24.0     55.0  29.7
# 51           1.0    101.0           50.0           15.0     36.0  24.2
# 389          3.0    100.0           68.0           23.0     81.0  31.6
# 303          5.0    115.0           98.0            0.0      0.0  52.9
# 563          6.0     99.0           60.0           19.0     54.0  26.9
# ..           ...      ...            ...            ...      ...   ...
# 428          0.0    135.0           94.0           46.0    145.0  40.6
# 291          0.0    107.0           62.0           30.0     74.0  36.6
# 58           0.0    146.0           82.0            0.0      0.0  40.5
# 528          0.0    117.0           66.0           31.0    188.0  30.8
# 193         11.0    135.0            0.0            0.0      0.0  52.3
#
#      DiabetesPedigreeFunction   Age  Outcome
# 174                     0.370  33.0      0.0
# 51                      0.526  26.0      0.0
# 389                     0.949  28.0      0.0
# 303                     0.209  28.0      1.0
# 563                     0.497  32.0      0.0
# ..                        ...   ...      ...
# 428                     0.284  26.0      0.0
# 291                     0.757  25.0      1.0
# 58                      1.781  44.0      0.0
# 528                     0.493  22.0      0.0
# 193                     0.578  40.0      1.0
#
# [606 rows x 9 columns]

# %%
y_train = traindf.pop(data_cl.get_label()[0])
X_train = traindf

# %%
y_test = testdf.pop(data_cl.get_label()[0])
X_test = testdf

# %%
testdf.compute().shape
# Out:
# (162, 8)

# %%
scaler_x = MinMaxScaler()
scaler_x.fit(X_train)
X_train = scaler_x.transform(X_train)
X_test = scaler_x.transform(X_test)

# %%
y_train = np.asarray(y_train).reshape([-1, 1])
y_test = np.asarray(y_test).reshape([-1, 1])

# %%
y_train.shape
# Out:
# (606, 1)

# %%
f = final.Final(X_train, y_train, X_test, y_test, "binary_crossentropy", 100, 64, input_shape = 8, 
                                   max_no_layers = 3, model_per_batch = 10, output_activation = "sigmoid")
f.get_all_best_models()
# Out:
# 2022-09-19 18:28:31.743357: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-09-19 18:28:31.744048: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-09-19 18:28:31.801207: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 18:28:31.801402: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.695GHz coreCount: 30 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 312.97GiB/s
# 2022-09-19 18:28:31.801438: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-19 18:28:31.803333: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-09-19 18:28:31.803389: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-09-19 18:28:31.805023: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-09-19 18:28:31.805316: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-09-19 18:28:31.807261: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-09-19 18:28:31.808315: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-09-19 18:28:31.812451: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-09-19 18:28:31.812621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 18:28:31.812880: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 18:28:31.813005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-09-19 18:28:31.813297: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-19 18:28:31.813567: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-09-19 18:28:31.813667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 18:28:31.813802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.695GHz coreCount: 30 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 312.97GiB/s
# 2022-09-19 18:28:31.813837: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-19 18:28:31.813860: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-09-19 18:28:31.813881: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-09-19 18:28:31.813901: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-09-19 18:28:31.813922: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-09-19 18:28:31.813942: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-09-19 18:28:31.813964: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-09-19 18:28:31.813984: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-09-19 18:28:31.814051: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 18:28:31.814230: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 18:28:31.814351: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-09-19 18:28:31.814394: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-19 18:28:32.261672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-09-19 18:28:32.261696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-09-19 18:28:32.261702: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-09-19 18:28:32.261877: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 18:28:32.262055: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 18:28:32.262196: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-19 18:28:32.262303: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 4789 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2022-09-19 18:28:32.514634: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-09-19 18:28:32.532625: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2899885000 Hz
# 2022-09-19 18:28:34.323710: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
#
#
#
# loss  :  4.138348579406738 , TEST :  5.162621974945068
# output_layer_dense_16_16_loss  :  0.44480663537979126 , TEST :  0.5009094476699829
# output_layer_dense_16_32_loss  :  0.4326070249080658 , TEST :  0.5101628303527832
# output_layer_dense_16_64_loss  :  0.42210322618484497 , TEST :  0.5194755792617798
# output_layer_dense_16_128_loss  :  0.40236786007881165 , TEST :  0.5263811349868774
# output_layer_dense_16_512_loss  :  0.3902077376842499 , TEST :  0.5427877902984619
# output_layer_dense_16_1024_loss  :  0.39159321784973145 , TEST :  0.5251652002334595
# output_layer_dense_32_16_loss  :  0.43506115674972534 , TEST :  0.4962383210659027
# output_layer_dense_32_32_loss  :  0.4169079065322876 , TEST :  0.5082557797431946
# output_layer_dense_32_64_loss  :  0.4023404121398926 , TEST :  0.5182384252548218
# output_layer_dense_32_128_loss  :  0.4003530442714691 , TEST :  0.5150068998336792
#
#
#
#
# loss  :  3.8436553478240967 , TEST :  5.370690822601318
# output_layer_dense_32_512_loss  :  0.37890625 , TEST :  0.5386678576469421
# output_layer_dense_32_1024_loss  :  0.3947675824165344 , TEST :  0.5307681560516357
# output_layer_dense_64_16_loss  :  0.41266700625419617 , TEST :  0.5268194079399109
# output_layer_dense_512_1024_1024_loss  :  0.07738111168146133 , TEST :  1.7383134365081787
#
#
#
#
# loss  :  3.0699169635772705 , TEST :  6.003729820251465
# output_layer_dense_1024_16_16_loss  :  0.3637077808380127 , TEST :  0.5614525079727173
# output_layer_dense_1024_32_16_loss  :  0.3425857424736023 , TEST :  0.5689054131507874
# output_layer_dense_1024_32_32_loss  :  0.3383384048938751 , TEST :  0.5590031147003174
# output_layer_dense_1024_64_16_loss  :  0.3136988878250122 , TEST :  0.5783349871635437
# output_layer_dense_1024_64_32_loss  :  0.3093195855617523 , TEST :  0.5716760158538818
# output_layer_dense_1024_64_64_loss  :  0.30352482199668884 , TEST :  0.5849885940551758
# output_layer_dense_1024_128_16_loss  :  0.3078782856464386 , TEST :  0.5767077207565308
# output_layer_dense_1024_128_32_loss  :  0.28501448035240173 , TEST :  0.6211856007575989
# output_layer_dense_1024_128_64_loss  :  0.2653481066226959 , TEST :  0.6527599096298218
# output_layer_dense_1024_128_128_loss  :  0.24050107598304749 , TEST :  0.7287163734436035
#
#
#
# loss  :  2.047292470932007 , TEST :  9.731767654418945
# output_layer_dense_1024_512_16_loss  :  0.27890917658805847 , TEST :  0.6716226935386658
# output_layer_dense_1024_512_32_loss  :  0.23690791428089142 , TEST :  0.7190542221069336
# output_layer_dense_1024_512_64_loss  :  0.19661501049995422 , TEST :  0.7916370630264282
# output_layer_dense_1024_512_128_loss  :  0.19514857232570648 , TEST :  0.8816705346107483
# output_layer_dense_1024_512_512_loss  :  0.1785265952348709 , TEST :  1.3234153985977173
# output_layer_dense_1024_1024_16_loss  :  0.23885557055473328 , TEST :  0.7329860329627991
# output_layer_dense_1024_1024_32_loss  :  0.1949121654033661 , TEST :  0.8971329927444458
# output_layer_dense_1024_1024_64_loss  :  0.18439365923404694 , TEST :  1.0115554332733154
# output_layer_dense_1024_1024_128_loss  :  0.1767769455909729 , TEST :  1.148890495300293
# output_layer_dense_1024_1024_512_loss  :  0.166246697306633 , TEST :  1.5538026094436646
#
#
#
#
# loss  :  0.15385057032108307 , TEST :  1.736397624015808
#
# -------------------------------------------------------------------------------
# [{'model_name': 'dense_16_16_512', 'score': 0.4784983992576599, 'path_weights': '/home/anish/AutoNN_test_weights/dense_16_16_512', 'model_conf': ['', 8, 3, 'relu', {'layer1': 16, 'layer2': 16, 'layer3': 512}, [1, 'sigmoid']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f1c91b7da00>}, {'model_name': 'dense_64_16_16', 'score': 0.4865608215332031, 'path_weights': '/home/anish/AutoNN_test_weights/dense_64_16_16', 'model_conf': ['', 8, 3, 'relu', {'layer1': 64, 'layer2': 16, 'layer3': 16}, [1, 'sigmoid']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f1c74382e20>}]
#
# -------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Model Name : dense_16_16_512_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.3940667510032654, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotUniform, BEST_LEARINING_RATE : 0.00398, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.3903411626815796
#
#
#
#
# loss  :  0.37505659461021423 , TEST :  0.5168079137802124
# 2022-09-19 18:36:57.269238: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_16_16_512_dr/assets
# --------------------------------------------------------------------------------
# Model Name : dense_64_16_16_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.3675350248813629, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotNormal, BEST_LEARINING_RATE : 0.01, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.37732893228530884
#
#
#
#
# loss  :  0.3120460510253906 , TEST :  0.7574242949485779
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_64_16_16_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_16_512_dr_st_dense_16_16_512_dr
# Model: "dense_16_16_512_dr_st_dense_16_16_512_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_16_512_ [(None, 8)]               0
# _________________________________________________________________
# layer1_dense_16_16_512_dr (D (None, 16)                144
# _________________________________________________________________
# layer2_dense_16_16_512_dr (D (None, 16)                272
# _________________________________________________________________
# layer3_dense_16_16_512_dr (D (None, 512)               8704
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# layer1_dense_16_16_512_dr_2n (None, 16)                8208
# _________________________________________________________________
# layer2_dense_16_16_512_dr_2n (None, 16)                272
# _________________________________________________________________
# layer3_dense_16_16_512_dr_2n (None, 512)               8704
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# output_layer_dense_16_16_512 (None, 1)                 513
# =================================================================
# Total params: 26,817
# Trainable params: 26,817
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.4016711413860321, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotNormal, BEST_LEARINING_RATE : 0.00501, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# GlorotNormal

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model("/home/anish/ASC_ML_test_weights/candidate_models/dense_64_64_16_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
model = load_model("/home/anish/ASC_ML_test_weights/candidate_models/dense_64_64_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
model = load_model("/home/anish/ASC_ML_test_weights/stacked_models/dense_64_64_16_dr_st_dense_64_64_16_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
model = load_model("/home/anish/ASC_ML_test_weights/stacked_models/dense_64_64_16_dr_st_dense_64_64_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
model = load_model("/home/anish/ASC_ML_test_weights/stacked_models/dense_64_64_dr_st_dense_64_64_16_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
model = load_model("/home/anish/ASC_ML_test_weights/stacked_models/dense_64_64_dr_st_dense_64_64_dr")
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.evaluate(X_train, y_train)

# %%
model.evaluate(X_test, y_test)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# making predictions on the testing set
y_pred = gnb.predict(X_test)

# comparing actual response values (y_test) with predicted response values (y_pred)
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)

# %%
y_pred_train = gnb.predict(X_train)
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_train, y_pred_train)*100)
