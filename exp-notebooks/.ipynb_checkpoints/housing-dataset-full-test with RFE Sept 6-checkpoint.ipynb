# %%
import numpy as np
import pandas as pd
# import plotly.express as px
# from autokeras import StructuredDataRegressor
from sklearn.model_selection import train_test_split
# from IPython.display import HTML
import os
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2022-09-05 21:43:36.711720: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import sys
import time
sys.path.insert(0, '/home/anish/ASC_ML')

# %%
from ASC_ML.networkbuilding import multiple_model_gen_v3 as multiple
from ASC_ML.networkbuilding import dataframe_extractor as de
from ASC_ML.networkbuilding import model_generation as model_gen
from ASC_ML.networkbuilding import model_optimization as model_opt
from ASC_ML.networkbuilding import model_stacking

# %%
from dask_ml.preprocessing import LabelEncoder
# from dask_ml.preprocessing import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# %%
directory1 = "/home/anish/ASC-ML-EXP-DATASETS/LinReg-tabular/house-prices-advanced-regression-techniques/train.csv"


# returns list of dask dataframe [singular_df_x, singular_df_y] or [train_df_x, train_df_y, test_df_x, test_df_y]
dataset_list = de.DataframeExtractor_csv(directory1, label_names = ["SalePrice"]).df_list

print("Train Dataset X Columns")
dataset_list[0].head()
# Out:
# Reading single csv from /home/anish/ASC-ML-EXP-DATASETS/LinReg-tabular/house-prices-advanced-regression-techniques/train.csv
# Train Dataset X Columns
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1.0        60.0       RL         65.0   8450.0   Pave   NaN      Reg
# 1  2.0        20.0       RL         80.0   9600.0   Pave   NaN      Reg
# 2  3.0        60.0       RL         68.0  11250.0   Pave   NaN      IR1
# 3  4.0        70.0       RL         60.0   9550.0   Pave   NaN      IR1
# 4  5.0        60.0       RL         84.0  14260.0   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...         0.0      0.0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...         0.0      0.0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...         0.0      0.0    NaN   NaN         NaN
# 3         Lvl    AllPub  ...         0.0      0.0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...         0.0      0.0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0     0.0    2.0  2008.0        WD         Normal
# 1     0.0    5.0  2007.0        WD         Normal
# 2     0.0    9.0  2008.0        WD         Normal
# 3     0.0    2.0  2006.0        WD        Abnorml
# 4     0.0   12.0  2008.0        WD         Normal
#
# [5 rows x 80 columns]

# %%
train_x = dataset_list[0].copy()
train_x = train_x.fillna(0)
train_x['MSSubClass'] = train_x['MSSubClass'].apply(str)
train_x['OverallCond'] = train_x['OverallCond'].astype(str)
train_x['YrSold'] = train_x['YrSold'].astype(str)
train_x['MoSold'] = train_x['MoSold'].astype(str)
# Out:
# /home/anish/anaconda3/envs/tfgpu/lib/python3.9/site-packages/dask/dataframe/core.py:3946: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('MSSubClass', 'object'))
#
#   warnings.warn(meta_warning(meta))

# %%
def keyval(allkeys):
    i = 0
    keyvalpairs = list()
    for key in allkeys:
        keyvalpairs.append((key,i))
        i+=1
    return dict(keyvalpairs)
cols = ['FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold']
keys = {}
for col in cols:
    key = train_x[col].unique()
    keyvalpairs = keyval(key)
    keys.update({col:keyvalpairs})

# %%
train_X = train_x.replace(keys).copy()
cols_to_remove = []
for col in train_X.columns:
#     print(type(col))
    try:
        a = train_X[col].astype(float).compute()
    except ValueError:
#         print('Couldn\'t covert %s to float' % col)
        cols_to_remove.append(col)
        pass

# keep only the columns in df that do not contain string
train_X = train_X[[col for col in train_X.columns if col not in cols_to_remove]]
train_X = train_X.drop(["Id"], axis = 1)

# %%
scaler_x = MinMaxScaler()
scaler_x.fit(train_X)
train_X_scaled = scaler_x.transform(train_X)

scaler_y = MinMaxScaler()
scaler_y.fit(dataset_list[1])
train_Y_scaled = scaler_y.transform(dataset_list[1])

# %%
import numpy as np
total_data = np.append(train_X_scaled, train_Y_scaled, axis = 1)
from sklearn.model_selection import train_test_split
(train, test) = train_test_split(total_data, test_size=0.25, random_state=42)
X_train = train[:,:58]
y_train = train[:,-1]
X_test = test[:,:58]
y_test = test[:,-1]

# %%
y_train = y_train.reshape((y_train.shape[0],1))
y_test = y_test.reshape((y_test.shape[0],1))

# %%
X_train.shape
# Out:
# (1095, 58)

# %%
start = time.time()
m = multiple.Multiple_Model_Gen_V3(X_train, y_train, X_test, y_test, 50, 64, input_shape = 58, 
                                   max_no_layers = 3, model_per_batch = 10, 
                                   save_dir = "/home/anish/ASC_ML_test_weights/")
m.get_model_confs()
m.get_best_models(save = False)
opt = model_opt.Model_Optimization(X_train, y_train, X_test, y_test, 200, m.evaluate_dict_list, save_dir = "/home/anish/ASC_ML_test_weights/candidate_models/")
opt.optimize_models(save=True)
stacked_models = model_stacking.Model_Stacking(X_train, y_train, X_test, y_test, opt.saved_paths, opt.model_confs, save_dir = "/home/anish/ASC_ML_test_weights/stacked_models/")
stacked_models.optimize_stacked_models()

end = time.time()
print("Time Taken : ", (end-start))
# Out:
# 2022-09-05 21:43:58.983746: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
#
#
#
# loss  :  0.15193229913711548 , TEST :  0.2884425222873688
# output_layer_dense_32_32_loss  :  0.01729872077703476 , TEST :  0.025728963315486908
# output_layer_dense_32_64_loss  :  0.017637794837355614 , TEST :  0.028626935556530952
# output_layer_dense_32_128_loss  :  0.018964704126119614 , TEST :  0.030719580128788948
# output_layer_dense_32_256_loss  :  0.012988993898034096 , TEST :  0.03047638200223446
# output_layer_dense_32_512_loss  :  0.013915164396166801 , TEST :  0.02726651541888714
# output_layer_dense_32_1024_loss  :  0.015199643559753895 , TEST :  0.028119483962655067
# output_layer_dense_64_32_loss  :  0.013662857003509998 , TEST :  0.030536554753780365
# output_layer_dense_64_64_loss  :  0.014764813706278801 , TEST :  0.028499247506260872
# output_layer_dense_64_128_loss  :  0.012919753789901733 , TEST :  0.0289174672216177
# output_layer_dense_64_256_loss  :  0.014579840935766697 , TEST :  0.02955138124525547
#
#
#
#
# loss  :  0.12320762872695923 , TEST :  0.2824208736419678
# output_layer_dense_64_512_loss  :  0.013376113958656788 , TEST :  0.029282720759510994
# output_layer_dense_64_1024_loss  :  0.009896616451442242 , TEST :  0.027409324422478676
# output_layer_dense_128_32_loss  :  0.015583708882331848 , TEST :  0.029382992535829544
# output_layer_dense_128_64_loss  :  0.0106614138931036 , TEST :  0.02998664788901806
# output_layer_dense_128_128_loss  :  0.013629486784338951 , TEST :  0.028412234038114548
# output_layer_dense_128_256_loss  :  0.01217864640057087 , TEST :  0.028387680649757385
# output_layer_dense_128_512_loss  :  0.010373189114034176 , TEST :  0.026743607595562935
# output_layer_dense_128_1024_loss  :  0.013291374780237675 , TEST :  0.029264410957694054
# output_layer_dense_256_32_loss  :  0.013196372427046299 , TEST :  0.026310039684176445
# output_layer_dense_256_64_loss  :  0.011020702309906483 , TEST :  0.02724120207130909
#
#
#
#
# loss  :  0.13086365163326263 , TEST :  0.26869773864746094
# output_layer_dense_256_128_loss  :  0.00947623886168003 , TEST :  0.02657332271337509
# output_layer_dense_256_256_loss  :  0.017874129116535187 , TEST :  0.03024550899863243
# output_layer_dense_256_512_loss  :  0.01373863872140646 , TEST :  0.026685331016778946
# output_layer_dense_256_1024_loss  :  0.009362669661641121 , TEST :  0.02552051469683647
# output_layer_dense_512_32_loss  :  0.010480078868567944 , TEST :  0.025608235970139503
# output_layer_dense_512_64_loss  :  0.01405972708016634 , TEST :  0.026475224643945694
# output_layer_dense_1024_1024_64_loss  :  0.010148141533136368 , TEST :  0.024253899231553078
# output_layer_dense_1024_1024_128_loss  :  0.01671328954398632 , TEST :  0.027966713532805443
# output_layer_dense_1024_1024_256_loss  :  0.010786022990942001 , TEST :  0.025237003341317177
# output_layer_dense_1024_1024_512_loss  :  0.008176911622285843 , TEST :  0.023688804358243942
#
#
#
#
# loss  :  0.010892963036894798 , TEST :  0.026253415271639824
#
# -------------------------------------------------------------------------------
# [{'model_name': 'dense_1024_1024_512', 'score': 0.023688804358243942, 'path_weights': '/home/anish/ASC_ML_test_weights/dense_1024_1024_512', 'model_conf': ['', 58, 3, 'relu', {'layer1': 1024, 'layer2': 1024, 'layer3': 512}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3d840a6340>}, {'model_name': 'dense_1024_64', 'score': 0.023788467049598694, 'path_weights': '/home/anish/ASC_ML_test_weights/dense_1024_64', 'model_conf': ['', 58, 2, 'relu', {'layer1': 1024, 'layer2': 64}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3d740a4dc0>}, {'model_name': 'dense_1024_512_128', 'score': 0.02395385131239891, 'path_weights': '/home/anish/ASC_ML_test_weights/dense_1024_512_128', 'model_conf': ['', 58, 3, 'relu', {'layer1': 1024, 'layer2': 512, 'layer3': 128}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3d747c4d30>}, {'model_name': 'dense_256_512_128', 'score': 0.02397242560982704, 'path_weights': '/home/anish/ASC_ML_test_weights/dense_256_512_128', 'model_conf': ['', 58, 3, 'relu', {'layer1': 256, 'layer2': 512, 'layer3': 128}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3d61db6a00>}, {'model_name': 'dense_512_512_256', 'score': 0.02413664199411869, 'path_weights': '/home/anish/ASC_ML_test_weights/dense_512_512_256', 'model_conf': ['', 58, 3, 'relu', {'layer1': 512, 'layer2': 512, 'layer3': 256}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3ef008af10>}, {'model_name': 'dense_1024_32_32', 'score': 0.024156656116247177, 'path_weights': '/home/anish/ASC_ML_test_weights/dense_1024_32_32', 'model_conf': ['', 58, 3, 'relu', {'layer1': 1024, 'layer2': 32, 'layer3': 32}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3d75558ee0>}, {'model_name': 'dense_1024_128_32', 'score': 0.024163343012332916, 'path_weights': '/home/anish/ASC_ML_test_weights/dense_1024_128_32', 'model_conf': ['', 58, 3, 'relu', {'layer1': 1024, 'layer2': 128, 'layer3': 32}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3ef05a8490>}, {'model_name': 'dense_512_64_64', 'score': 0.02421836368739605, 'path_weights': '/home/anish/ASC_ML_test_weights/dense_512_64_64', 'model_conf': ['', 58, 3, 'relu', {'layer1': 512, 'layer2': 64, 'layer3': 64}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3ef00b6e50>}, {'model_name': 'dense_1024_1024_64', 'score': 0.024253899231553078, 'path_weights': '/home/anish/ASC_ML_test_weights/dense_1024_1024_64', 'model_conf': ['', 58, 3, 'relu', {'layer1': 1024, 'layer2': 1024, 'layer3': 64}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3d747c48e0>}, {'model_name': 'dense_1024_256_128', 'score': 0.02432086691260338, 'path_weights': '/home/anish/ASC_ML_test_weights/dense_1024_256_128', 'model_conf': ['', 58, 3, 'relu', {'layer1': 1024, 'layer2': 256, 'layer3': 128}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f3ef05a9250>}]
#
# -------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Model Name : dense_1024_1024_512
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.018085097894072533, BEST_ACTIVATION : selu, BEST_INITIALIZER : LecunNormal, BEST_LEARINING_RATE : 3e-05, BEST_BATCHSIZE : 32
#
#
#
#
# loss  :  0.019887972623109818 , TEST :  0.038568079471588135
# 2022-09-05 21:47:35.705796: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# --------------------------------------------------------------------------------
# Model Name : dense_1024_64
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.02007736638188362, BEST_ACTIVATION : selu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 5e-05, BEST_BATCHSIZE : 16
#
#
#
#
# loss  :  0.020848426967859268 , TEST :  0.036818601191043854
# --------------------------------------------------------------------------------
# Model Name : dense_1024_512_128
