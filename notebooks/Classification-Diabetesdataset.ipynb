# %%
import sys
import time
sys.path.insert(0, '/home/anish/AutoNN')

# %%
from AutoNN.preprocessing import data_cleaning
from AutoNN.preprocessing import encoding_v2 as enc
from AutoNN.main import AutoNN
import dask.dataframe as dd
from AutoNN.networkbuilding import final
import numpy as np
import pandas as pd
# Out:
# ░█▀▀█ █░░█ ▀▀█▀▀ █▀▀█ ▒█▄░▒█ ▒█▄░▒█
# ▒█▄▄█ █░░█ ░░█░░ █░░█ ▒█▒█▒█ ▒█▒█▒█
# ▒█░▒█ ░▀▀▀ ░░▀░░ ▀▀▀▀ ▒█░░▀█ ▒█░░▀█
#
# An AutoML framework by
# Anish Konar, Arjun Ghosh, Rajarshi Banerjee, Sagnik Nayak.
# 2022-10-13 18:18:41.406025: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import time

# %%
# autonn = AutoNN("/home/anish/Downloads/winequality-red.csv", "quality")
autonn = AutoNN("/home/anish/Downloads/diabetes1.csv", "Outcome")
# autonn = AutoNN("/home/anish/Downloads/house-prices-advanced-regression-techniques/train.csv", "SalePrice")

# %%
start = time.time()
autonn.preprocessing()
end = time.time()
# Out:
# [(0.003284072249589491, 'Glucose'), (0.014778325123152709, 'BMI'), (0.04926108374384237, 'BloodPressure'), (0.14285714285714285, 'Pregnancies')]
# (159, 1)

# %%
print(f"Time Taken {end-start}s")
# Out:
# Time Taken 1.6469089984893799s

# %%
start = time.time()
autonn.neuralnetworkgeneration()
end = time.time()
# Out:
# 2022-10-13 18:19:20.994701: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-13 18:19:20.998527: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-10-13 18:19:21.079621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-13 18:19:21.079761: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.695GHz coreCount: 30 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 312.97GiB/s
# 2022-10-13 18:19:21.079783: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-13 18:19:21.091602: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-10-13 18:19:21.091641: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-10-13 18:19:21.097980: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-13 18:19:21.099788: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-13 18:19:21.112333: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-13 18:19:21.114579: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-10-13 18:19:21.161689: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-10-13 18:19:21.162113: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-13 18:19:21.162851: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-13 18:19:21.163282: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-13 18:19:21.164163: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-13 18:19:21.165441: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-13 18:19:21.165813: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-13 18:19:21.166303: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.695GHz coreCount: 30 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 312.97GiB/s
# 2022-10-13 18:19:21.166409: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-13 18:19:21.166489: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-10-13 18:19:21.166563: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-10-13 18:19:21.166635: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-13 18:19:21.166706: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-13 18:19:21.166779: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-13 18:19:21.166901: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-10-13 18:19:21.166957: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-10-13 18:19:21.167138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-13 18:19:21.167591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-13 18:19:21.167883: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-13 18:19:21.168355: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-13 18:19:21.835068: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-13 18:19:21.835091: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-10-13 18:19:21.835097: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-10-13 18:19:21.835509: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-13 18:19:21.835686: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-13 18:19:21.835825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-13 18:19:21.835930: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5017 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2022-10-13 18:19:22.102830: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-10-13 18:19:22.125378: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2899885000 Hz
# 2022-10-13 18:19:23.923571: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
#
#
#
# loss  :  4.241858005523682 , TEST :  4.68337345123291
# output_layer_dense_16_16_loss  :  0.45345228910446167 , TEST :  0.44766196608543396
# output_layer_dense_16_64_loss  :  0.4472354054450989 , TEST :  0.4507983326911926
# output_layer_dense_16_128_loss  :  0.4200623631477356 , TEST :  0.47047194838523865
# output_layer_dense_16_512_loss  :  0.43243804574012756 , TEST :  0.45392709970474243
# output_layer_dense_16_1024_loss  :  0.42119958996772766 , TEST :  0.46251967549324036
# output_layer_dense_64_16_loss  :  0.43657225370407104 , TEST :  0.4610739052295685
# output_layer_dense_64_64_loss  :  0.4176628589630127 , TEST :  0.47796764969825745
# output_layer_dense_512_1024_512_loss  :  0.26029372215270996 , TEST :  0.6205669045448303
# output_layer_dense_512_1024_1024_loss  :  0.17796626687049866 , TEST :  0.7415183186531067
#
#
#
#
# loss  :  3.6077585220336914 , TEST :  5.182794570922852
# output_layer_dense_1024_16_16_loss  :  0.4059024751186371 , TEST :  0.48606422543525696
# output_layer_dense_1024_64_16_loss  :  0.38759252429008484 , TEST :  0.49733662605285645
# output_layer_dense_1024_64_64_loss  :  0.3795540928840637 , TEST :  0.5127916932106018
# output_layer_dense_1024_128_16_loss  :  0.3757343888282776 , TEST :  0.5024932026863098
# output_layer_dense_1024_128_64_loss  :  0.37812381982803345 , TEST :  0.5246745944023132
# output_layer_dense_1024_128_128_loss  :  0.3609875738620758 , TEST :  0.5204566717147827
# output_layer_dense_1024_512_16_loss  :  0.38052865862846375 , TEST :  0.5194262862205505
# output_layer_dense_1024_512_64_loss  :  0.3327448070049286 , TEST :  0.5336100459098816
# output_layer_dense_1024_512_128_loss  :  0.30928710103034973 , TEST :  0.5418503880500793
# output_layer_dense_1024_512_512_loss  :  0.2973036468029022 , TEST :  0.5440908670425415
#
#
#
#
# loss  :  1.4194817543029785 , TEST :  2.8620009422302246
# output_layer_dense_1024_1024_16_loss  :  0.37822628021240234 , TEST :  0.5073269605636597
# output_layer_dense_1024_1024_64_loss  :  0.30880007147789 , TEST :  0.5240043997764587
# output_layer_dense_1024_1024_128_loss  :  0.30230045318603516 , TEST :  0.5275737047195435
# output_layer_dense_1024_1024_512_loss  :  0.23529623448848724 , TEST :  0.6155686974525452
# output_layer_dense_1024_1024_1024_loss  :  0.1948588639497757 , TEST :  0.6875272393226624
#
# -------------------------------------------------------------------------------
# [{'model_name': 'dense_16_16_512', 'score': 0.43790876865386963, 'path_weights': '/home/anish/AutoNN_test_weights/dense_16_16_512', 'model_conf': ['', 6, 3, 'relu', {'layer1': 16, 'layer2': 16, 'layer3': 512}, [1, 'sigmoid']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f555c76ec70>}, {'model_name': 'dense_16_16', 'score': 0.44766196608543396, 'path_weights': '/home/anish/AutoNN_test_weights/dense_16_16', 'model_conf': ['', 6, 2, 'relu', {'layer1': 16, 'layer2': 16}, [1, 'sigmoid']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f561c0829a0>}, {'model_name': 'dense_16_64', 'score': 0.4507983326911926, 'path_weights': '/home/anish/AutoNN_test_weights/dense_16_64', 'model_conf': ['', 6, 2, 'relu', {'layer1': 16, 'layer2': 64}, [1, 'sigmoid']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f55e0251910>}, {'model_name': 'dense_16_512', 'score': 0.45392709970474243, 'path_weights': '/home/anish/AutoNN_test_weights/dense_16_512', 'model_conf': ['', 6, 2, 'relu', {'layer1': 16, 'layer2': 512}, [1, 'sigmoid']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f55e0247df0>}, {'model_name': 'dense_16_128_16', 'score': 0.4577377140522003, 'path_weights': '/home/anish/AutoNN_test_weights/dense_16_128_16', 'model_conf': ['', 6, 3, 'relu', {'layer1': 16, 'layer2': 128, 'layer3': 16}, [1, 'sigmoid']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f555c68da60>}]
#
# -------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Model Name : dense_16_16_512_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.4059500992298126, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00316, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : 0.2, BEST_DROPOUT_LOSS : 0.3967183232307434
#
#
#
#
# loss  :  0.3870173990726471 , TEST :  0.4950801432132721
# --------------------------------------------------------------------------------
# Model Name : dense_16_16_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.4315430521965027, BEST_ACTIVATION : tanh, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.01, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.4303659498691559
#
#
#
#
# loss  :  0.3918442130088806 , TEST :  0.47586214542388916
# --------------------------------------------------------------------------------
# Model Name : dense_16_64_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.4234210252761841, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00794, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.4007549285888672
#
#
#
#
# loss  :  0.400229275226593 , TEST :  0.48475924134254456
# --------------------------------------------------------------------------------
# Model Name : dense_16_512_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.3996179699897766, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00398, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.3790344297885895
#
#
#
#
# loss  :  0.28243494033813477 , TEST :  0.5663114190101624
# --------------------------------------------------------------------------------
# Model Name : dense_16_128_16_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.4167267382144928, BEST_ACTIVATION : selu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.01995, BEST_BATCHSIZE : 128, BEST_DROPOUT_RATE : 0.2, BEST_DROPOUT_LOSS : 0.41441258788108826
#
#
#
#
# loss  :  0.3995872139930725 , TEST :  0.5007674694061279
# [{'model_name': 'dense_16_16_dr', 'score': 0.47586214542388916, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_16_16_dr', 'model_conf': ['', 6, 2, 'relu', {'layer1': 16, 'layer2': 16}, [1, 'sigmoid'], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f538a2c0610>}, {'model_name': 'dense_16_64_dr', 'score': 0.48475924134254456, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_16_64_dr', 'model_conf': ['', 6, 2, 'relu', {'layer1': 16, 'layer2': 64}, [1, 'sigmoid'], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f534b876b20>}, {'model_name': 'dense_16_16_512_dr', 'score': 0.4950801432132721, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_16_16_512_dr', 'model_conf': ['', 6, 3, 'relu', {'layer1': 16, 'layer2': 16, 'layer3': 512}, [1, 'sigmoid'], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f5579e17fa0>}]
# 2022-10-13 18:35:06.225036: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_16_16_dr/assets
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_16_64_dr/assets
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_16_16_512_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_16_dr_st_dense_16_64_dr
# Model: "dense_16_16_dr_st_dense_16_64_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_16_dr ( [(None, 6)]               0
# _________________________________________________________________
# layer1_dense_16_16_dr (Dense (None, 16)                112
# _________________________________________________________________
# layer2_dense_16_16_dr (Dense (None, 16)                272
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# layer1_dense_16_64_dr_2nd (D (None, 16)                272
# _________________________________________________________________
# layer2_dense_16_64_dr_2nd (D (None, 64)                1088
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output_layer_dense_16_64_dr  (None, 1)                 65
# =================================================================
# Total params: 1,809
# Trainable params: 1,809
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.407897025346756, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.01, BEST_BATCHSIZE : 64, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# HeUniform
# DROPOUT RATES : [0.5, 0]
# TRAIN_LOSS = 0.5320955514907837, TEST_LOSS = 0.5680518746376038
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_16_16_dr_st_dense_16_64_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_16_dr_st_dense_16_16_512_dr
# Model: "dense_16_16_dr_st_dense_16_16_512_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_16_dr ( [(None, 6)]               0
# _________________________________________________________________
# layer1_dense_16_16_dr (Dense (None, 16)                112
# _________________________________________________________________
# layer2_dense_16_16_dr (Dense (None, 16)                272
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 16)                0
# _________________________________________________________________
# layer1_dense_16_16_512_dr_2n (None, 16)                272
# _________________________________________________________________
# layer2_dense_16_16_512_dr_2n (None, 16)                272
# _________________________________________________________________
# layer3_dense_16_16_512_dr_2n (None, 512)               8704
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# output_layer_dense_16_16_512 (None, 1)                 513
# =================================================================
# Total params: 10,145
# Trainable params: 10,145
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.4019331932067871, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00501, BEST_BATCHSIZE : 64, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# HeUniform
# DROPOUT RATES : [0.5, 0.2]
# TRAIN_LOSS = 0.8656631112098694, TEST_LOSS = 0.8637868762016296
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_16_16_dr_st_dense_16_16_512_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_64_dr_st_dense_16_16_dr
# Model: "dense_16_64_dr_st_dense_16_16_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_64_dr ( [(None, 6)]               0
# _________________________________________________________________
# layer1_dense_16_64_dr (Dense (None, 16)                112
# _________________________________________________________________
# layer2_dense_16_64_dr (Dense (None, 64)                1088
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# layer1_dense_16_16_dr_2nd (D (None, 16)                1040
# _________________________________________________________________
# layer2_dense_16_16_dr_2nd (D (None, 16)                272
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 16)                0
# _________________________________________________________________
# output_layer_dense_16_16_dr  (None, 1)                 17
# =================================================================
# Total params: 2,529
# Trainable params: 2,529
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.4208749234676361, BEST_ACTIVATION : tanh, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00501, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# HeUniform
# DROPOUT RATES : [0.5, 0.2]
# TRAIN_LOSS = 0.41869157552719116, TEST_LOSS = 0.531413733959198
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_16_64_dr_st_dense_16_16_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_64_dr_st_dense_16_16_512_dr
# Model: "dense_16_64_dr_st_dense_16_16_512_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_64_dr ( [(None, 6)]               0
# _________________________________________________________________
# layer1_dense_16_64_dr (Dense (None, 16)                112
# _________________________________________________________________
# layer2_dense_16_64_dr (Dense (None, 64)                1088
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 64)                0
# _________________________________________________________________
# layer1_dense_16_16_512_dr_2n (None, 16)                1040
# _________________________________________________________________
# layer2_dense_16_16_512_dr_2n (None, 16)                272
# _________________________________________________________________
# layer3_dense_16_16_512_dr_2n (None, 512)               8704
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 512)               0
# _________________________________________________________________
# output_layer_dense_16_16_512 (None, 1)                 513
# =================================================================
# Total params: 11,729
# Trainable params: 11,729
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.4078366756439209, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00251, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# HeUniform
# DROPOUT RATES : [0.5, 0]
# TRAIN_LOSS = 0.36815810203552246, TEST_LOSS = 0.4979119598865509
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_16_64_dr_st_dense_16_16_512_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_16_512_dr_st_dense_16_16_dr
# Model: "dense_16_16_512_dr_st_dense_16_16_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_16_512_ [(None, 6)]               0
# _________________________________________________________________
# layer1_dense_16_16_512_dr (D (None, 16)                112
# _________________________________________________________________
# layer2_dense_16_16_512_dr (D (None, 16)                272
# _________________________________________________________________
# layer3_dense_16_16_512_dr (D (None, 512)               8704
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 512)               0
# _________________________________________________________________
# layer1_dense_16_16_dr_2nd (D (None, 16)                8208
# _________________________________________________________________
# layer2_dense_16_16_dr_2nd (D (None, 16)                272
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 16)                0
# _________________________________________________________________
# output_layer_dense_16_16_dr  (None, 1)                 17
# =================================================================
# Total params: 17,585
# Trainable params: 17,585
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.4151687026023865, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00158, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# LecunUniform
# DROPOUT RATES : [0.5, 0.2]
# TRAIN_LOSS = 0.34879791736602783, TEST_LOSS = 0.6125829219818115
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_16_16_512_dr_st_dense_16_16_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_16_512_dr_st_dense_16_64_dr
# Model: "dense_16_16_512_dr_st_dense_16_64_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_16_512_ [(None, 6)]               0
# _________________________________________________________________
# layer1_dense_16_16_512_dr (D (None, 16)                112
# _________________________________________________________________
# layer2_dense_16_16_512_dr (D (None, 16)                272
# _________________________________________________________________
# layer3_dense_16_16_512_dr (D (None, 512)               8704
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# _________________________________________________________________
# layer1_dense_16_64_dr_2nd (D (None, 16)                8208
# _________________________________________________________________
# layer2_dense_16_64_dr_2nd (D (None, 64)                1088
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer_dense_16_64_dr  (None, 1)                 65
# =================================================================
# Total params: 18,449
# Trainable params: 18,449
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.4068198502063751, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00631, BEST_BATCHSIZE : 64, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# HeUniform
# DROPOUT RATES : [0.5, 0.2]
# TRAIN_LOSS = 0.33266276121139526, TEST_LOSS = 0.7726531624794006
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_16_16_512_dr_st_dense_16_64_dr/assets

# %%
print(f"Time Taken {end-start}s")
# Out:
# Time Taken 2365.044017314911s
