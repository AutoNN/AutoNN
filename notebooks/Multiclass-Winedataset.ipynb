# %%
import sys
import time
sys.path.insert(0, '/home/anish/AutoNN')

# %%
from AutoNN.preprocessing import data_cleaning
from AutoNN.preprocessing import encoding_v2 as enc
from AutoNN.main import AutoNN
import dask.dataframe as dd
from AutoNN.networkbuilding import final
import numpy as np
import pandas as pd
# Out:
# ░█▀▀█ █░░█ ▀▀█▀▀ █▀▀█ ▒█▄░▒█ ▒█▄░▒█
# ▒█▄▄█ █░░█ ░░█░░ █░░█ ▒█▒█▒█ ▒█▒█▒█
# ▒█░▒█ ░▀▀▀ ░░▀░░ ▀▀▀▀ ▒█░░▀█ ▒█░░▀█
#
# An AutoML framework by
# Anish Konar, Arjun Ghosh, Rajarshi Banerjee, Sagnik Nayak.
# 2022-10-14 17:44:41.796386: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import time

# %%
autonn = AutoNN("/home/anish/Downloads/winequality-red.csv", "quality")
# autonn = AutoNN("/home/anish/Downloads/diabetes1.csv", "Outcome")
# autonn = AutoNN("/home/anish/Downloads/house-prices-advanced-regression-techniques/train.csv", "SalePrice")

# %%
start = time.time()
autonn.preprocessing()
end = time.time()
# Out:
# []
# CATEGORICAL
# (1307, 6)

# %%
print(f"Time Taken {end-start}s")
# Out:
# Time Taken 0.9671893119812012s

# %%
start = time.time()
autonn.neuralnetworkgeneration()
end = time.time()
# Out:
# 2022-10-14 17:44:48.838233: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-14 17:44:48.842831: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-10-14 17:44:48.937553: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-14 17:44:48.937852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.695GHz coreCount: 30 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 312.97GiB/s
# 2022-10-14 17:44:48.937911: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-14 17:44:48.952009: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-10-14 17:44:48.952073: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-10-14 17:44:48.959731: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-14 17:44:48.961846: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-14 17:44:48.976812: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-14 17:44:48.979780: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-10-14 17:44:49.008090: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-10-14 17:44:49.008272: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-14 17:44:49.008544: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-14 17:44:49.008696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-14 17:44:49.009067: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-14 17:44:49.009507: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-10-14 17:44:49.009646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-14 17:44:49.009816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.695GHz coreCount: 30 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 312.97GiB/s
# 2022-10-14 17:44:49.009859: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-14 17:44:49.009889: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-10-14 17:44:49.009915: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-10-14 17:44:49.009942: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-10-14 17:44:49.009968: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-10-14 17:44:49.009994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-10-14 17:44:49.010022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-10-14 17:44:49.010049: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-10-14 17:44:49.010142: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-14 17:44:49.010365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-14 17:44:49.010510: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-10-14 17:44:49.010851: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-10-14 17:44:49.694172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-14 17:44:49.694195: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-10-14 17:44:49.694201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-10-14 17:44:49.694595: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-14 17:44:49.694770: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-14 17:44:49.694955: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-14 17:44:49.695067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 4988 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2022-10-14 17:44:49.957465: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-10-14 17:44:49.975001: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2899885000 Hz
# 2022-10-14 17:44:51.537751: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
#
#
#
# loss  :  8.504888534545898 , TEST :  10.102336883544922
# output_layer_dense_16_16_loss  :  0.9262301325798035 , TEST :  1.0079879760742188
# output_layer_dense_16_64_loss  :  0.8885407447814941 , TEST :  1.014238715171814
# output_layer_dense_16_128_loss  :  0.8926202654838562 , TEST :  1.009741187095642
# output_layer_dense_16_512_loss  :  0.8479818105697632 , TEST :  0.9969682097434998
# output_layer_dense_16_1024_loss  :  0.8152930736541748 , TEST :  1.0397582054138184
# output_layer_dense_64_16_loss  :  0.8792672157287598 , TEST :  1.0067256689071655
# output_layer_dense_64_64_loss  :  0.8521867394447327 , TEST :  1.0140483379364014
# output_layer_dense_64_128_loss  :  0.8427423238754272 , TEST :  0.9966590404510498
# output_layer_dense_64_512_loss  :  0.7901148200035095 , TEST :  0.9950283765792847
# output_layer_dense_64_1024_loss  :  0.7699106335639954 , TEST :  1.0211799144744873
#
#
#
#
# loss  :  7.748103141784668 , TEST :  10.100025177001953
# output_layer_dense_128_16_loss  :  0.8578020930290222 , TEST :  0.9915907382965088
# output_layer_dense_128_64_loss  :  0.8338380455970764 , TEST :  0.9893224239349365
# output_layer_dense_128_128_loss  :  0.8140987753868103 , TEST :  1.0039454698562622
# output_layer_dense_128_512_loss  :  0.7759040594100952 , TEST :  0.9931408762931824
# output_layer_dense_128_1024_loss  :  0.7431060075759888 , TEST :  0.9983459711074829
# output_layer_dense_512_16_loss  :  0.8498879075050354 , TEST :  0.9839308261871338
# output_layer_dense_512_64_loss  :  0.8003323078155518 , TEST :  0.9945047497749329
# output_layer_dense_512_128_loss  :  0.7811303734779358 , TEST :  0.9961062669754028
# output_layer_dense_512_512_loss  :  0.6758753657341003 , TEST :  1.062785029411316
# output_layer_dense_512_1024_loss  :  0.6161283254623413 , TEST :  1.0863529443740845
#
#
#
#
# loss  :  3.560413122177124 , TEST :  5.309696197509766
# output_layer_dense_1024_16_loss  :  0.8071033954620361 , TEST :  1.009806513786316
# output_layer_dense_1024_64_loss  :  0.7739467620849609 , TEST :  1.0092154741287231
# output_layer_dense_1024_128_loss  :  0.7460811138153076 , TEST :  1.0272880792617798
# output_layer_dense_1024_512_loss  :  0.6525539755821228 , TEST :  1.07999587059021
# output_layer_dense_1024_1024_loss  :  0.5807271599769592 , TEST :  1.1833901405334473
#
#
#
#
# loss  :  8.568116188049316 , TEST :  10.128522872924805
# output_layer_dense_16_16_16_loss  :  0.8889801502227783 , TEST :  0.9980528354644775
# output_layer_dense_16_16_64_loss  :  0.8941749334335327 , TEST :  0.9940242767333984
# output_layer_dense_16_16_128_loss  :  0.8793551325798035 , TEST :  1.0058393478393555
# output_layer_dense_16_16_512_loss  :  0.8868340849876404 , TEST :  0.9921560287475586
# output_layer_dense_16_16_1024_loss  :  0.8326283097267151 , TEST :  1.016532063484192
# output_layer_dense_16_64_16_loss  :  0.9002224802970886 , TEST :  1.0098379850387573
# output_layer_dense_16_64_64_loss  :  0.8488074541091919 , TEST :  1.0322363376617432
# output_layer_dense_16_64_128_loss  :  0.835655927658081 , TEST :  1.0049773454666138
# output_layer_dense_16_64_512_loss  :  0.7945530414581299 , TEST :  1.0413169860839844
# output_layer_dense_16_64_1024_loss  :  0.8069040179252625 , TEST :  1.0335502624511719
#
#
#
#
# loss  :  7.899292469024658 , TEST :  10.35010814666748
# output_layer_dense_16_128_16_loss  :  0.8787797689437866 , TEST :  1.0030217170715332
# output_layer_dense_16_128_64_loss  :  0.8463306427001953 , TEST :  1.0013880729675293
# output_layer_dense_16_128_128_loss  :  0.8542467355728149 , TEST :  1.018692970275879
# output_layer_dense_16_128_512_loss  :  0.7451550364494324 , TEST :  1.0223240852355957
# output_layer_dense_16_128_1024_loss  :  0.7084351181983948 , TEST :  1.1105200052261353
# output_layer_dense_16_512_16_loss  :  0.8791685104370117 , TEST :  1.0297075510025024
# output_layer_dense_16_512_64_loss  :  0.8065437078475952 , TEST :  1.041277527809143
# output_layer_dense_16_512_128_loss  :  0.7262237668037415 , TEST :  1.0906219482421875
# output_layer_dense_1024_128_64_loss  :  0.7165165543556213 , TEST :  1.0177119970321655
# output_layer_dense_1024_128_128_loss  :  0.687415361404419 , TEST :  1.0183504819869995
# output_layer_dense_1024_512_16_loss  :  0.736792802810669 , TEST :  0.9728164672851562
# output_layer_dense_1024_512_64_loss  :  0.6131282448768616 , TEST :  1.1235167980194092
# output_layer_dense_1024_512_128_loss  :  0.5649627447128296 , TEST :  1.1600100994110107
# output_layer_dense_1024_512_512_loss  :  0.4781053364276886 , TEST :  1.4315083026885986
#
#
#
#
# loss  :  2.415074586868286 , TEST :  6.915810585021973
# output_layer_dense_1024_1024_16_loss  :  0.6698254942893982 , TEST :  1.0530022382736206
# output_layer_dense_1024_1024_64_loss  :  0.5209196209907532 , TEST :  1.2406582832336426
# output_layer_dense_1024_1024_128_loss  :  0.481828898191452 , TEST :  1.3030184507369995
# output_layer_dense_1024_1024_512_loss  :  0.38714319467544556 , TEST :  1.5756405591964722
# output_layer_dense_1024_1024_1024_loss  :  0.35535773634910583 , TEST :  1.7434908151626587
#
# -------------------------------------------------------------------------------
# [{'model_name': 'dense_1024_64_16', 'score': 0.9712486863136292, 'path_weights': '/home/anish/AutoNN_test_weights/dense_1024_64_16', 'model_conf': ['', 11, 3, 'relu', {'layer1': 1024, 'layer2': 64, 'layer3': 16}, [6, 'softmax']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fedc4acfac0>}, {'model_name': 'dense_1024_512_16', 'score': 0.9728164672851562, 'path_weights': '/home/anish/AutoNN_test_weights/dense_1024_512_16', 'model_conf': ['', 11, 3, 'relu', {'layer1': 1024, 'layer2': 512, 'layer3': 16}, [6, 'softmax']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fedc4968280>}, {'model_name': 'dense_64_1024_16', 'score': 0.9806041121482849, 'path_weights': '/home/anish/AutoNN_test_weights/dense_64_1024_16', 'model_conf': ['', 11, 3, 'relu', {'layer1': 64, 'layer2': 1024, 'layer3': 16}, [6, 'softmax']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fedb0566490>}, {'model_name': 'dense_128_64_64', 'score': 0.982140839099884, 'path_weights': '/home/anish/AutoNN_test_weights/dense_128_64_64', 'model_conf': ['', 11, 3, 'relu', {'layer1': 128, 'layer2': 64, 'layer3': 64}, [6, 'softmax']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fedb05552e0>}, {'model_name': 'dense_512_16', 'score': 0.9839308261871338, 'path_weights': '/home/anish/AutoNN_test_weights/dense_512_16', 'model_conf': ['', 11, 2, 'relu', {'layer1': 512, 'layer2': 16}, [6, 'softmax']], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fedb01c2190>}]
#
# -------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Model Name : dense_1024_64_16_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.7143734693527222, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.002, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.541299045085907
#
#
#
#
# loss  :  0.28225433826446533 , TEST :  2.081357717514038
# --------------------------------------------------------------------------------
# Model Name : dense_1024_512_16_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.6622901558876038, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00251, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.415973961353302
#
#
#
#
# loss  :  0.04824918136000633 , TEST :  3.3953299522399902
# --------------------------------------------------------------------------------
# Model Name : dense_64_1024_16_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.7378972172737122, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00794, BEST_BATCHSIZE : 64, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.5688934922218323
#
#
#
#
# loss  :  0.24956955015659332 , TEST :  2.0954456329345703
# --------------------------------------------------------------------------------
# Model Name : dense_128_64_64_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.6875789761543274, BEST_ACTIVATION : tanh, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00316, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.32108575105667114
#
#
#
#
# loss  :  0.06110908091068268 , TEST :  1.9212133884429932
# --------------------------------------------------------------------------------
# Model Name : dense_512_16_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.7823672890663147, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.01, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.6297031044960022
#
#
#
#
# loss  :  0.5433968305587769 , TEST :  1.3412383794784546
# [{'model_name': 'dense_512_16_dr', 'score': 1.3412383794784546, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_512_16_dr', 'model_conf': ['', 11, 2, 'relu', {'layer1': 512, 'layer2': 16}, [6, 'softmax'], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7feb0de5b2b0>}, {'model_name': 'dense_128_64_64_dr', 'score': 1.9212133884429932, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_128_64_64_dr', 'model_conf': ['', 11, 3, 'relu', {'layer1': 128, 'layer2': 64, 'layer3': 64}, [6, 'softmax'], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7feb4c51fb20>}, {'model_name': 'dense_1024_64_16_dr', 'score': 2.081357717514038, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_1024_64_16_dr', 'model_conf': ['', 11, 3, 'relu', {'layer1': 1024, 'layer2': 64, 'layer3': 16}, [6, 'softmax'], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fedc4c39370>}]
# 2022-10-14 18:14:24.064495: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_512_16_dr/assets
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_128_64_64_dr/assets
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_1024_64_16_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_512_16_dr_st_dense_128_64_64_dr
# Model: "dense_512_16_dr_st_dense_128_64_64_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_512_16_dr  [(None, 11)]              0
# _________________________________________________________________
# layer1_dense_512_16_dr (Dens (None, 512)               6144
# _________________________________________________________________
# layer2_dense_512_16_dr (Dens (None, 16)                8208
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# layer1_dense_128_64_64_dr_2n (None, 128)               2176
# _________________________________________________________________
# layer2_dense_128_64_64_dr_2n (None, 64)                8256
# _________________________________________________________________
# layer3_dense_128_64_64_dr_2n (None, 64)                4160
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# output_layer_dense_128_64_64 (None, 6)                 390
# =================================================================
# Total params: 29,334
# Trainable params: 29,334
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.765143632888794, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00398, BEST_BATCHSIZE : 64, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# LecunUniform
# DROPOUT RATES : [0.5, 0]
# TRAIN_LOSS = 1.0810850858688354, TEST_LOSS = 1.207021951675415
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_512_16_dr_st_dense_128_64_64_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_512_16_dr_st_dense_1024_64_16_dr
# Model: "dense_512_16_dr_st_dense_1024_64_16_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_512_16_dr  [(None, 11)]              0
# _________________________________________________________________
# layer1_dense_512_16_dr (Dens (None, 512)               6144
# _________________________________________________________________
# layer2_dense_512_16_dr (Dens (None, 16)                8208
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 16)                0
# _________________________________________________________________
# layer1_dense_1024_64_16_dr_2 (None, 1024)              17408
# _________________________________________________________________
# layer2_dense_1024_64_16_dr_2 (None, 64)                65600
# _________________________________________________________________
# layer3_dense_1024_64_16_dr_2 (None, 16)                1040
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 16)                0
# _________________________________________________________________
# output_layer_dense_1024_64_1 (None, 6)                 102
# =================================================================
# Total params: 98,502
# Trainable params: 98,502
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.7450857758522034, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00251, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# LecunUniform
# DROPOUT RATES : [0.5, 0.5]
# TRAIN_LOSS = 1.1927976608276367, TEST_LOSS = 1.152549386024475
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_512_16_dr_st_dense_1024_64_16_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_128_64_64_dr_st_dense_512_16_dr
# Model: "dense_128_64_64_dr_st_dense_512_16_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_128_64_64_ [(None, 11)]              0
# _________________________________________________________________
# layer1_dense_128_64_64_dr (D (None, 128)               1536
# _________________________________________________________________
# layer2_dense_128_64_64_dr (D (None, 64)                8256
# _________________________________________________________________
# layer3_dense_128_64_64_dr (D (None, 64)                4160
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# layer1_dense_512_16_dr_2nd ( (None, 512)               33280
# _________________________________________________________________
# layer2_dense_512_16_dr_2nd ( (None, 16)                8208
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 16)                0
# _________________________________________________________________
# output_layer_dense_512_16_dr (None, 6)                 102
# =================================================================
# Total params: 55,542
# Trainable params: 55,542
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.6605705618858337, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00251, BEST_BATCHSIZE : 64, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# HeUniform
# DROPOUT RATES : [0.5, 0.5]
# TRAIN_LOSS = 0.5833439230918884, TEST_LOSS = 1.4545265436172485
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_128_64_64_dr_st_dense_512_16_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_128_64_64_dr_st_dense_1024_64_16_dr
# Model: "dense_128_64_64_dr_st_dense_1024_64_16_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_128_64_64_ [(None, 11)]              0
# _________________________________________________________________
# layer1_dense_128_64_64_dr (D (None, 128)               1536
# _________________________________________________________________
# layer2_dense_128_64_64_dr (D (None, 64)                8256
# _________________________________________________________________
# layer3_dense_128_64_64_dr (D (None, 64)                4160
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 64)                0
# _________________________________________________________________
# layer1_dense_1024_64_16_dr_2 (None, 1024)              66560
# _________________________________________________________________
# layer2_dense_1024_64_16_dr_2 (None, 64)                65600
# _________________________________________________________________
# layer3_dense_1024_64_16_dr_2 (None, 16)                1040
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 16)                0
# _________________________________________________________________
# output_layer_dense_1024_64_1 (None, 6)                 102
# =================================================================
# Total params: 147,254
# Trainable params: 147,254
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.596207320690155, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.002, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# HeUniform
# DROPOUT RATES : [0.5, 0.5]
# TRAIN_LOSS = 0.5154561996459961, TEST_LOSS = 1.4483685493469238
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_128_64_64_dr_st_dense_1024_64_16_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_1024_64_16_dr_st_dense_512_16_dr
# Model: "dense_1024_64_16_dr_st_dense_512_16_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_1024_64_16 [(None, 11)]              0
# _________________________________________________________________
# layer1_dense_1024_64_16_dr ( (None, 1024)              12288
# _________________________________________________________________
# layer2_dense_1024_64_16_dr ( (None, 64)                65600
# _________________________________________________________________
# layer3_dense_1024_64_16_dr ( (None, 16)                1040
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 16)                0
# _________________________________________________________________
# layer1_dense_512_16_dr_2nd ( (None, 512)               8704
# _________________________________________________________________
# layer2_dense_512_16_dr_2nd ( (None, 16)                8208
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 16)                0
# _________________________________________________________________
# output_layer_dense_512_16_dr (None, 6)                 102
# =================================================================
# Total params: 95,942
# Trainable params: 95,942
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.7416197657585144, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00631, BEST_BATCHSIZE : 128, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# LecunUniform
# DROPOUT RATES : [0.5, 0.5]
# TRAIN_LOSS = 0.9036502838134766, TEST_LOSS = 1.1999435424804688
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_1024_64_16_dr_st_dense_512_16_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_1024_64_16_dr_st_dense_128_64_64_dr
# Model: "dense_1024_64_16_dr_st_dense_128_64_64_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_1024_64_16 [(None, 11)]              0
# _________________________________________________________________
# layer1_dense_1024_64_16_dr ( (None, 1024)              12288
# _________________________________________________________________
# layer2_dense_1024_64_16_dr ( (None, 64)                65600
# _________________________________________________________________
# layer3_dense_1024_64_16_dr ( (None, 16)                1040
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 16)                0
# _________________________________________________________________
# layer1_dense_128_64_64_dr_2n (None, 128)               2176
# _________________________________________________________________
# layer2_dense_128_64_64_dr_2n (None, 64)                8256
# _________________________________________________________________
# layer3_dense_128_64_64_dr_2n (None, 64)                4160
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer_dense_128_64_64 (None, 6)                 390
# =================================================================
# Total params: 93,910
# Trainable params: 93,910
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.724362313747406, BEST_ACTIVATION : tanh, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.001, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# HeUniform
# DROPOUT RATES : [0.5, 0.5]
# TRAIN_LOSS = 0.6056230068206787, TEST_LOSS = 1.1378337144851685
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_1024_64_16_dr_st_dense_128_64_64_dr/assets

# %%
print(f"Time Taken {end-start}s")
# Out:
# Time Taken 2365.044017314911s
