# %%
import sys
import time
sys.path.insert(0, '/home/anish/AutoNN')

# %%
from AutoNN.preprocessing import data_cleaning
from AutoNN.preprocessing import encoding_v2 as enc
import dask.dataframe as dd
from AutoNN.networkbuilding import final
import numpy as np
import pandas as pd
# Out:
# ░█▀▀█ █░░█ ▀▀█▀▀ █▀▀█ ▒█▄░▒█ ▒█▄░▒█
# ▒█▄▄█ █░░█ ░░█░░ █░░█ ▒█▒█▒█ ▒█▒█▒█
# ▒█░▒█ ░▀▀▀ ░░▀░░ ▀▀▀▀ ▒█░░▀█ ▒█░░▀█
#
# An AutoML framework by
# Anish Konar, Arjun Ghosh, Rajarshi Banerjee, Sagnik Nayak.
# 2022-09-29 22:47:17.889065: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import time

# %%
class AutoNN:
    def __init__(self, train_csv_path, label_name, loss = None):
        self._train_csv_path = train_csv_path
        self._label_name = label_name
        self._output_shape = None
        self._output_activation = None
        self._loss = loss
        
        self._train_X = None
        self._train_Y = None
        self._test_X = None
        self._test_Y = None
        
        self._input_shape = None
        
        self._EDA_data_container = None
    
    def preprocessing(self):
        df = dd.read_csv(self._train_csv_path, assume_missing=True, sample_rows=2000)
        d_clean = data_cleaning.DataCleaning(label = [self._label_name], train_dataframe=df)
        d_clean.dataset.train_test_split()
        d_clean.parse_dates()
        d_clean.generate_column_info()
        # d_clean.column_info
        encoder = enc.Encoding()

        train, validation, test = d_clean.dataset.get(['train', 'validation', 'test'])

        for column in d_clean.column_info.keys():
            if d_clean.column_info[column]['dtype'] == 'object':
                encoder.fit_column(column = train[column], column_name=column, label_name = self._label_name)
        train, validation, test = d_clean.dataset.get(['train', 'validation', 'test'])
        d_clean.dataset.set(encoder.label_encode(train), type = 'train')

        if validation is not None:
            d_clean.dataset.set(encoder.label_encode(validation), type = 'validation')
        if test is not None:
            d_clean.dataset.set(encoder.label_encode(test), type = 'test')


        d_clean.clean_data()
        
        self._EDA_data_container = d_clean.dataset()
        
        d_clean.feature_elimination_fit(type = "train", method = "correlation")
        d_clean.eliminate_features(type = "train")
        if validation is not None:
            d_clean.eliminate_features(type = "validation")
        if test is not None:
            d_clean.eliminate_features(type = "test")
            

#         train, validation, test = d_clean.dataset.get(['train', 'validation', 'test'])
# #         EDA DATA
#         self._EDA_train = train
#         self._EDA_test = test
        
        d_clean.dataset.set(encoder.inverse_label_encode(train), type = 'train')
        if validation is not None:
            d_clean.dataset.set(encoder.inverse_label_encode(validation), type = 'validation')
        if test is not None:
            d_clean.dataset.set(encoder.inverse_label_encode(test), type = 'test')
    
        train, validation, test = d_clean.dataset.get(['train', 'validation', 'test'])
        d_clean.generate_column_info()
        
        reg_clas_flag, label_cardinality = d_clean.is_regression()
        categorical_flag = False
        if reg_clas_flag == 1:
            self._output_shape = 1
            self._output_activation = None
            loss = "mean_squared_error"
        elif reg_clas_flag == 0 and label_cardinality == 2:
            self._output_shape = 1
            self._output_activation = "sigmoid"
            loss = "binary_crossentropy"
        elif reg_clas_flag == 0 and label_cardinality > 2:
            self._output_shape = label_cardinality
            self._output_activation = "softmax"
            loss = "categorical_crossentropy"
            categorical_flag = True
            print("CATEGORICAL")
#             d_clean.dataset.set(train.categorize(self._label_name), type = 'train')        
            
        if self._loss == None:
            self._loss = loss
            
        train, validation, test = d_clean.dataset.get(['train', 'validation', 'test'])
                    
        train_Y = train[self._label_name].to_frame()
        test_Y = test[self._label_name].to_frame()
        
        train_X = train.drop(self._label_name, axis = 1).copy()
        test_X = test.drop(self._label_name, axis = 1).copy()
        
        onehot_encoder_X = enc.Encoding()
        onehot_encoder_X.onehot_fit(train_X)
        
        train_X = onehot_encoder_X.onehot_encode(train_X)
        if validation is not None:
            d_clean.dataset.set(onehot_encoder_X.onehot_encode(validation), type = 'validation')
        if test is not None:
            test_X = onehot_encoder_X.onehot_encode(test_X)
        
        if categorical_flag:
            train_Y = train_Y.categorize()
            test_Y = test_Y.categorize()
            pr
            onehot_encoder_Y = enc.Encoding()
            onehot_encoder_Y.onehot_fit(train_Y)
            train_Y = onehot_encoder_Y.onehot_encode(train_Y)
            if test is not None:
                test_Y = onehot_encoder_Y.onehot_encode(test_Y)
                        
        d_clean.scaling_fit(train_X)
        train_X = d_clean.scaling_transform(train_X)
        if test is not None:
            test_X = d_clean.scaling_transform(test_X)
        
        if not categorical_flag:
            d_clean.scaling_fit(train_Y)
            train_Y = d_clean.scaling_transform(train_Y)
            if test is not None:
                test_Y = d_clean.scaling_transform(test_Y)
        
        self._train_X = np.asarray(train_X)
        self._train_Y = np.asarray(train_Y)
        self._test_X = np.asarray(test_X)
        self._test_Y = np.asarray(test_Y)
        print(self._test_Y.shape)
        
        self._input_shape = train_X.shape[-1]
        
#         return train, validation, test, train_Y, test_Y
    def neuralnetworkgeneration(self):
        f = final.Final(self._train_X, self._train_Y, self._test_X, self._test_Y, self._loss, 75, 64, input_shape = self._input_shape, 
                                   max_no_layers = 3, model_per_batch = 10, 
                        output_shape = self._output_shape, output_activation = self._output_activation)
        f.get_all_best_models()

# %%
# autonn = AutoNN("/home/anish/Downloads/winequality-red.csv", "quality")
# autonn = AutoNN("/home/anish/Downloads/diabetes1.csv", "Outcome")
autonn = AutoNN("/home/anish/Downloads/house-prices-advanced-regression-techniques/train.csv", "SalePrice")

# %%
start = time.time()
autonn.preprocessing()
end = time.time()
# Out:
# [(0.0008496176720475786, 'Electrical'), (0.00594732370433305, 'MasVnrArea'), (0.00594732370433305, 'MasVnrType'), (0.028037383177570093, 'BsmtCond'), (0.028037383177570093, 'BsmtFinType1'), (0.028037383177570093, 'BsmtQual'), (0.02888700084961767, 'BsmtExposure'), (0.02888700084961767, 'BsmtFinType2'), (0.05777400169923534, 'GarageCond'), (0.05777400169923534, 'GarageFinish'), (0.05777400169923534, 'GarageQual'), (0.05777400169923534, 'GarageType'), (0.05777400169923534, 'GarageYrBlt'), (0.16992353440951571, 'LotFrontage')]
# (283, 1)

# %%
print(f"Time Taken {end-start}s")
# Out:
# Time Taken 71.45998334884644s

# %%
start = time.time()
autonn.neuralnetworkgeneration()
end = time.time()
# Out:
# 2022-09-29 22:48:30.134797: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-09
# output_layer_dense_1024_512_16_loss  :  0.00011920357792405412 , TEST :  0.003675086423754692
# output_layer_dense_1024_512_64_loss  :  9.085090277949348e-05 , TEST :  0.0033663474023342133
# output_layer_dense_1024_512_128_loss  :  8.238328155130148e-05 , TEST :  0.003754987847059965
# output_layer_dense_1024_512_512_loss  :  7.228132017189637e-05 , TEST :  0.003137117251753807
#
#
#
#
# loss  :  0.001012250897474587 , TEST :  0.017673324793577194
# output_layer_dense_1024_1024_16_loss  :  0.0002302738867001608 , TEST :  0.0037996801547706127
# output_layer_dense_1024_1024_64_loss  :  0.00012325380521360785 , TEST :  0.00332077220082283
# output_layer_dense_1024_1024_128_loss  :  0.00014474429190158844 , TEST :  0.00332195358350873
# output_layer_dense_1024_1024_512_loss  :  0.00036292485310696065 , TEST :  0.003709312528371811
# output_layer_dense_1024_1024_1024_loss  :  0.00015105403144843876 , TEST :  0.003521605860441923
#
# -------------------------------------------------------------------------------
# [{'model_name': 'dense_16_64_16', 'score': 0.002500728238373995, 'path_weights': '/home/anish/AutoNN_test_weights/dense_16_64_16', 'model_conf': ['', 72, 3, 'relu', {'layer1': 16, 'layer2': 64, 'layer3': 16}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fe4fc685160>}, {'model_name': 'dense_512_16_16', 'score': 0.0026172625366598368, 'path_weights': '/home/anish/AutoNN_test_weights/dense_512_16_16', 'model_conf': ['', 72, 3, 'relu', {'layer1': 512, 'layer2': 16, 'layer3': 16}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fe5401fcdc0>}, {'model_name': 'dense_16_64', 'score': 0.0026762248016893864, 'path_weights': '/home/anish/AutoNN_test_weights/dense_16_64', 'model_conf': ['', 72, 2, 'relu', {'layer1': 16, 'layer2': 64}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fe5a00cf6d0>}, {'model_name': 'dense_16_128_128', 'score': 0.002740194322541356, 'path_weights': '/home/anish/AutoNN_test_weights/dense_16_128_128', 'model_conf': ['', 72, 3, 'relu', {'layer1': 16, 'layer2': 128, 'layer3': 128}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fe58c052cd0>}, {'model_name': 'dense_16_16_128', 'score': 0.0027728420682251453, 'path_weights': '/home/anish/AutoNN_test_weights/dense_16_16_128', 'model_conf': ['', 72, 3, 'relu', {'layer1': 16, 'layer2': 16, 'layer3': 128}, [1, None]], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fe4fc67de80>}]
#
# -------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Model Name : dense_16_64_16_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.0012783072888851166, BEST_ACTIVATION : tanh, BEST_INITIALIZER : GlorotUniform, BEST_LEARINING_RATE : 0.02512, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.5, BEST_DROPOUT_LOSS : 0.0010677868267521262
#
#
#
#
# loss  :  0.006525401026010513 , TEST :  0.007309164851903915
# --------------------------------------------------------------------------------
# Model Name : dense_512_16_16_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.0004837877058889717, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00398, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.0003462491149548441
#
#
#
#
# loss  :  0.00020947599841747433 , TEST :  0.0036665310617536306
# --------------------------------------------------------------------------------
# Model Name : dense_16_64_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.001061781425960362, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00398, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.0, BEST_DROPOUT_LOSS : 0.0008879881934262812
#
#
#
#
# loss  :  0.0008498186361975968 , TEST :  0.003951219841837883
# --------------------------------------------------------------------------------
# Model Name : dense_16_128_128_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.001155627192929387, BEST_ACTIVATION : tanh, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00794, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.2, BEST_DROPOUT_LOSS : 0.002071183640509844
#
#
#
#
# loss  :  0.0012610016856342554 , TEST :  0.0035997810773551464
# --------------------------------------------------------------------------------
# Model Name : dense_16_16_128_dr
#
# BEST HYPERPARAMETERS : BEST_LOSS : 0.0010671683121472597, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotUniform, BEST_LEARINING_RATE : 0.01, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : 0.2, BEST_DROPOUT_LOSS : 0.0016996373888105154
#
#
#
#
# loss  :  0.0012351578334346414 , TEST :  0.004410158842802048
# [{'model_name': 'dense_16_128_128_dr', 'score': 0.0035997810773551464, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_16_128_128_dr', 'model_conf': ['', 72, 3, 'relu', {'layer1': 16, 'layer2': 128, 'layer3': 128}, [1, None], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fe2d9ba08b0>}, {'model_name': 'dense_512_16_16_dr', 'score': 0.0036665310617536306, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_512_16_16_dr', 'model_conf': ['', 72, 3, 'relu', {'layer1': 512, 'layer2': 16, 'layer3': 16}, [1, None], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fe51c281b50>}, {'model_name': 'dense_16_64_dr', 'score': 0.003951219841837883, 'path_weights': '/home/anish/AutoNN_test_weights/candidate_models/dense_16_64_dr', 'model_conf': ['', 72, 2, 'relu', {'layer1': 16, 'layer2': 64}, [1, None], True], 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fe30d777ca0>}]
# 2022-09-29 23:18:15.612340: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_16_128_128_dr/assets
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_512_16_16_dr/assets
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/candidate_models/dense_16_64_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_128_128_dr_st_dense_512_16_16_dr
# Model: "dense_16_128_128_dr_st_dense_512_16_16_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_128_128 [(None, 72)]              0
# _________________________________________________________________
# layer1_dense_16_128_128_dr ( (None, 16)                1168
# _________________________________________________________________
# layer2_dense_16_128_128_dr ( (None, 128)               2176
# _________________________________________________________________
# layer3_dense_16_128_128_dr ( (None, 128)               16512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# layer1_dense_512_16_16_dr_2n (None, 512)               66048
# _________________________________________________________________
# layer2_dense_512_16_16_dr_2n (None, 16)                8208
# _________________________________________________________________
# layer3_dense_512_16_16_dr_2n (None, 16)                272
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 16)                0
# _________________________________________________________________
# output_layer_dense_512_16_16 (None, 1)                 17
# =================================================================
# Total params: 94,401
# Trainable params: 94,401
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.000986710307188332, BEST_ACTIVATION : relu, BEST_INITIALIZER : GlorotUniform, BEST_LEARINING_RATE : 0.00126, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# GlorotUniform
# DROPOUT RATES : [0.5, 0.2]
# TRAIN_LOSS = 0.0025210806634277105, TEST_LOSS = 0.0046789199113845825
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_16_128_128_dr_st_dense_512_16_16_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_128_128_dr_st_dense_16_64_dr
# Model: "dense_16_128_128_dr_st_dense_16_64_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_128_128 [(None, 72)]              0
# _________________________________________________________________
# layer1_dense_16_128_128_dr ( (None, 16)                1168
# _________________________________________________________________
# layer2_dense_16_128_128_dr ( (None, 128)               2176
# _________________________________________________________________
# layer3_dense_16_128_128_dr ( (None, 128)               16512
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# layer1_dense_16_64_dr_2nd (D (None, 16)                2064
# _________________________________________________________________
# layer2_dense_16_64_dr_2nd (D (None, 64)                1088
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer_dense_16_64_dr  (None, 1)                 65
# =================================================================
# Total params: 23,073
# Trainable params: 23,073
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.0011861857492476702, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00316, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# LecunUniform
# DROPOUT RATES : [0.5, 0.5]
# TRAIN_LOSS = 0.0008739476907067001, TEST_LOSS = 0.0029859868809580803
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_16_128_128_dr_st_dense_16_64_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_512_16_16_dr_st_dense_16_128_128_dr
# Model: "dense_512_16_16_dr_st_dense_16_128_128_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_512_16_16_ [(None, 72)]              0
# _________________________________________________________________
# layer1_dense_512_16_16_dr (D (None, 512)               37376
# _________________________________________________________________
# layer2_dense_512_16_16_dr (D (None, 16)                8208
# _________________________________________________________________
# layer3_dense_512_16_16_dr (D (None, 16)                272
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16)                0
# _________________________________________________________________
# layer1_dense_16_128_128_dr_2 (None, 16)                272
# _________________________________________________________________
# layer2_dense_16_128_128_dr_2 (None, 128)               2176
# _________________________________________________________________
# layer3_dense_16_128_128_dr_2 (None, 128)               16512
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer_dense_16_128_12 (None, 1)                 129
# =================================================================
# Total params: 64,945
# Trainable params: 64,945
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.00047530359006486833, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00316, BEST_BATCHSIZE : 16, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# LecunUniform
# DROPOUT RATES : [0.5, 0.5]
# TRAIN_LOSS = 0.011998241767287254, TEST_LOSS = 0.013077827170491219
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_512_16_16_dr_st_dense_16_128_128_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_512_16_16_dr_st_dense_16_64_dr
# Model: "dense_512_16_16_dr_st_dense_16_64_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_512_16_16_ [(None, 72)]              0
# _________________________________________________________________
# layer1_dense_512_16_16_dr (D (None, 512)               37376
# _________________________________________________________________
# layer2_dense_512_16_16_dr (D (None, 16)                8208
# _________________________________________________________________
# layer3_dense_512_16_16_dr (D (None, 16)                272
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 16)                0
# _________________________________________________________________
# layer1_dense_16_64_dr_2nd (D (None, 16)                272
# _________________________________________________________________
# layer2_dense_16_64_dr_2nd (D (None, 64)                1088
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 64)                0
# _________________________________________________________________
# output_layer_dense_16_64_dr  (None, 1)                 65
# =================================================================
# Total params: 47,281
# Trainable params: 47,281
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.0004926779656670988, BEST_ACTIVATION : relu, BEST_INITIALIZER : HeUniform, BEST_LEARINING_RATE : 0.00316, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# HeUniform
# DROPOUT RATES : [0.2, 0.5]
# TRAIN_LOSS = 0.0007065783138386905, TEST_LOSS = 0.003233877243474126
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_512_16_16_dr_st_dense_16_64_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_64_dr_st_dense_16_128_128_dr
# Model: "dense_16_64_dr_st_dense_16_128_128_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_64_dr ( [(None, 72)]              0
# _________________________________________________________________
# layer1_dense_16_64_dr (Dense (None, 16)                1168
# _________________________________________________________________
# layer2_dense_16_64_dr (Dense (None, 64)                1088
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 64)                0
# _________________________________________________________________
# layer1_dense_16_128_128_dr_2 (None, 16)                1040
# _________________________________________________________________
# layer2_dense_16_128_128_dr_2 (None, 128)               2176
# _________________________________________________________________
# layer3_dense_16_128_128_dr_2 (None, 128)               16512
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output_layer_dense_16_128_12 (None, 1)                 129
# =================================================================
# Total params: 22,113
# Trainable params: 22,113
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.0008176913834176958, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00251, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# LecunUniform
# DROPOUT RATES : [0.5, 0.5]
# TRAIN_LOSS = 0.0011280756443738937, TEST_LOSS = 0.002946082502603531
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_16_64_dr_st_dense_16_128_128_dr/assets
# -------------------------------------------------------------------------------------------------------------------
# dense_16_64_dr_st_dense_512_16_16_dr
# Model: "dense_16_64_dr_st_dense_512_16_16_dr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer_dense_16_64_dr ( [(None, 72)]              0
# _________________________________________________________________
# layer1_dense_16_64_dr (Dense (None, 16)                1168
# _________________________________________________________________
# layer2_dense_16_64_dr (Dense (None, 64)                1088
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 64)                0
# _________________________________________________________________
# layer1_dense_512_16_16_dr_2n (None, 512)               33280
# _________________________________________________________________
# layer2_dense_512_16_16_dr_2n (None, 16)                8208
# _________________________________________________________________
# layer3_dense_512_16_16_dr_2n (None, 16)                272
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 16)                0
# _________________________________________________________________
# output_layer_dense_512_16_16 (None, 1)                 17
# =================================================================
# Total params: 44,033
# Trainable params: 44,033
# Non-trainable params: 0
# _________________________________________________________________
# None
# BEST HYPERPARAMETERS : BEST_LOSS : 0.0013728041667491198, BEST_ACTIVATION : relu, BEST_INITIALIZER : LecunUniform, BEST_LEARINING_RATE : 0.00251, BEST_BATCHSIZE : 32, BEST_DROPOUT_RATE : None, BEST_DROPOUT_LOSS : None
# LecunUniform
# DROPOUT RATES : [0.5, 0.5]
# TRAIN_LOSS = 0.003123244270682335, TEST_LOSS = 0.004902598913758993
# INFO:tensorflow:Assets written to: /home/anish/AutoNN_test_weights/stacked_models/dense_16_64_dr_st_dense_512_16_16_dr/assets

# %%
print(f"Time Taken {end-start}s")
# Out:
# Time Taken 4262.250415325165s
